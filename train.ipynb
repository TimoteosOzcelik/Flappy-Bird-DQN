# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.6/dist-packages (2.0.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ['SDL_VIDEODRIVER']='dummy'

import math
import random
import pygame
import numpy as np
import pickle
from collections import namedtuple
from itertools import count
from PIL import Image
from pygame.surfarray import array3d, pixels_alpha

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %%
torch.cuda.empty_cache()

# %%
class Environment():
    pygame.init()

    width, height = (288, 512)
    screen = pygame.display.set_mode((width, height))

    clock = pygame.time.Clock()
    fps = 30

    # Background
    background = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/background-day.png").convert()

    # Floor
    floor = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/base.png").convert()
    floor_limit = background.get_width() - floor.get_width()

    # Bird
    bird_downflap = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/yellowbird-downflap.png").convert_alpha()
    bird_midflap = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/yellowbird-midflap.png").convert_alpha()
    bird_upflap = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/yellowbird-upflap.png").convert_alpha()

    bird_index = 0
    bird_frames = [bird_downflap, bird_midflap, bird_upflap]
    bird = bird_frames[bird_index]

    bird_hitmask = [pixels_alpha(image).astype(bool) for image in bird_frames]

    init_pos = (
        int(width * 0.2),
        int(height / 2)
    )

    # Pipe
    pipe_surface = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/pipe-green.png").convert_alpha()
    pipes = []

    '''
    pipe_gap = 100
    pipe_min = int(pipe_gap / 4)
    pipe_max = int(height * 0.79 * 0.6 - pipe_gap / 2)
    '''

    pipe_gap = 125

    pipe_min = 1
    pipe_max = 5


    def __init__(self):
        self.floorx, self.floory = (0, self.background.get_height() - self.floor.get_height())
        self.bird_rect = self.bird.get_rect(center=self.init_pos)

        # Game variables
        self.GRAVITY = 1
        self.FLAP_POWER = 9
        self.MAX_DROP_SPEED = 15

        # Velocity on y and x
        self.vel = 0
        self.speed = 4

        # Score
        self.score = 0

        self.tick = 0

        self.pipes.extend(self._generate_pipes(offset=int(0.5 * self.width)))
        self.pipes.extend(self._generate_pipes(offset=int(0.5 * self.pipe_surface.get_width() + self.width)))


    def _generate_pipes(self, offset=0):
        # gap_start = random.randint(self.pipe_min, self.pipe_max)
        gap_start = random.randint(self.pipe_min, self.pipe_max+1)*25 + 50

        top_bottom = gap_start - self.pipe_surface.get_height()
        bottom_top = gap_start + self.pipe_gap

        top_pipe = self.pipe_surface.get_rect(topleft=(self.width + offset, top_bottom))
        bottom_pipe = self.pipe_surface.get_rect(topleft=(self.width + offset, bottom_top))

        return top_pipe, bottom_pipe


    def _is_collided(self):
        # out-of-screen
        if self.bird_rect.top <= - self.bird.get_height() * 0.5 or self.bird_rect.bottom >= self.floory:
            return True

        # mask = self.bird_hitmask[self.bird_index]
        mask = pixels_alpha(self.rotate_bird()).astype(bool)
        rows, columns = mask.shape

        # pipe collison
        for pipe in self.pipes:
            lx, rx = pipe.x, pipe.x + self.pipe_surface.get_width()
            ty, by = pipe.y, pipe.y + self.pipe_surface.get_height()

            for i in range(rows):
                for j in range(columns):
                    posx, posy = self.bird_rect.x + j, self.bird_rect.y + i
                    if mask[i, j] and lx < posx < rx and ty < posy < by:
                        return True

            '''      
            if self.bird_rect.colliderect(pipe):
                return True
            '''

        return False


    def rotate_bird(self):
        return pygame.transform.rotozoom(self.bird, -self.vel * 3, 1)


    def bird_animation(self):
        new_bird = self.bird_frames[self.bird_index]
        new_bird_rect = new_bird.get_rect(center=(100, self.bird_rect.centery))
        return new_bird, new_bird_rect


    def step(self, action):
        pygame.event.pump()

        # reward to stay alive
        reward = 0.1

        # terminal
        terminal = False

        # update tick
        self.tick += 1

        # Velocity updating
        if self.vel < self.MAX_DROP_SPEED:
            self.vel += self.GRAVITY

        if action == 1:
            self.vel = 0
            self.vel -= self.FLAP_POWER

        # bird movement
        self.bird_rect.centery += self.vel

        # floor movement
        self.floorx -= 1
        if self.floorx < self.floor_limit:
            self.floorx = 0

        # pipes' movement
        for pipe in self.pipes:
            pipe.centerx -= self.speed

        # Check whether bird passes the pipe or not
        for pipe in self.pipes:
            if pipe.centerx < self.bird_rect.centerx <= pipe.centerx + self.speed:
                reward = 1
                self.score += 1
                break

        # Update pipes
        if self.pipes[0].x <= -self.pipe_surface.get_width():
            self.pipes.extend(self._generate_pipes())

        # delete top and bottom pipes
        if self.pipes[0].x <= -self.pipe_surface.get_width():
            del self.pipes[0]
            del self.pipes[0]

        if (self.tick + 1) % 15 == 0:
            self.bird_index = (self.bird_index + 1) % 3
            self.bird, self.bird_rect = self.bird_animation()

        if self._is_collided():
            reward = -1
            terminal = True

        # draw
        self.screen.blit(self.background, (0, 0))

        for i, pipe in enumerate(self.pipes):
            if i % 2 == 0:
                flip_pipe = pygame.transform.flip(self.pipe_surface, False, True)
                self.screen.blit(flip_pipe, pipe)
            else:
                self.screen.blit(self.pipe_surface, pipe)

        self.screen.blit(self.floor, (self.floorx, self.floory))

        rotated_bird = self.rotate_bird()
        self.screen.blit(rotated_bird, self.bird_rect)

        # self.screen.blit(self.bird, self.bird_rect)

        pygame.display.update()
        screen = array3d(pygame.display.get_surface())
        self.clock.tick(self.fps)

        return screen, reward, terminal
        
        
    def get_screen(self):
        return array3d(pygame.display.get_surface())


    def reset(self):
        self.pipes.clear()
        self.__init__()
        
    
    def quit(self):
        pygame.quit()

# %%
class Environment():
    pygame.init()

    width, height = (288, 512)
    screen = pygame.display.set_mode((width, height))

    clock = pygame.time.Clock()
    fps = 30

    # Background
    background = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/background-day.png").convert()

    # Floor
    floor = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/base.png").convert()
    floor_limit = background.get_width() - floor.get_width()

    # Bird
    bird_downflap = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/yellowbird-downflap.png").convert_alpha()
    bird_midflap = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/yellowbird-midflap.png").convert_alpha()
    bird_upflap = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/yellowbird-upflap.png").convert_alpha()

    bird_index = 0
    bird_frames = [bird_downflap, bird_midflap, bird_upflap]
    bird = bird_frames[bird_index]

    bird_hitmask = [pixels_alpha(image).astype(bool) for image in bird_frames]

    init_pos = (
        int(width * 0.2),
        int(height / 2)
    )

    # Pipe
    pipe_surface = pygame.image.load("/content/drive/MyDrive/Colab_Notebooks/FlappyBird/assets/sprites/pipe-green.png").convert_alpha()
    pipes = []

    pipe_gap = 125
    pipe_min = 1
    pipe_max = 5

    def _init_(self):
        self.floorx, self.floory = (0, self.background.get_height() - self.floor.get_height())
        # self.floorx, self.floory = (0, self.height * 0.79)
        self.bird_rect = self.bird.get_rect(center=self.init_pos)

        # Game variables
        self.GRAVITY = 1
        self.FLAP_POWER = 9
        self.MAX_DROP_SPEED = 15

        # Velocity on y and x
        self.vel = 0
        self.speed = 4

        # Score
        self.score = 0

        self.tick = 0

        self.pipes.extend(self._generate_pipes(offset=(0.5 * self.width)))
        self.pipes.extend(self._generate_pipes(offset=int(0.5 * self.pipe_surface.get_width() + self.width)))


    def _generate_pipes(self, offset=0):
        # gap_start = random.randint(self.pipe_min, self.pipe_max)
        gap_start = random.randint(self.pipe_min, self.pipe_max + 1) * 25 + 50

        top_bottom = gap_start - self.pipe_surface.get_height()
        bottom_top = gap_start + self.pipe_gap

        top_pipe = self.pipe_surface.get_rect(topleft=(self.width + offset, top_bottom))
        bottom_pipe = self.pipe_surface.get_rect(topleft=(self.width + offset, bottom_top))

        return top_pipe, bottom_pipe


    def _is_collided(self):
        # out-of-screen
        if self.bird_rect.top < - self.bird.get_height() * 0.1 or self.bird_rect.bottom >= self.floory:
            return True

        # mask = self.bird_hitmask[self.bird_index]
        mask = pixels_alpha(self.rotate_bird()).astype(bool)
        rows, columns = mask.shape

        # pipe collison
        for pipe in self.pipes:
            lx, rx = pipe.x, pipe.x + self.pipe_surface.get_width()
            ty, by = pipe.y, pipe.y + self.pipe_surface.get_height()

            for i in range(rows):
                for j in range(columns):
                    # posx, posy = self.bird_rect.x + j, self.bird_rect.y + i
                    posx, posy = self.bird_rect.x + i, self.bird_rect.y + j
                    if mask[i, j] and lx < posx < rx and ty < posy < by:
                        return True

        return False


    def rotate_bird(self):
        return pygame.transform.rotozoom(self.bird, -self.vel * 3, 1)


    def bird_animation(self):
        new_bird = self.bird_frames[self.bird_index]
        new_bird_rect = new_bird.get_rect(center=(100, self.bird_rect.centery))
        return new_bird, new_bird_rect


    def step(self, action):
        pygame.event.pump()

        # reward to stay alive
        reward = 0.1

        # terminal
        terminal = False

        self.tick += 1

        # Velocity updating
        if self.vel < self.MAX_DROP_SPEED:
            self.vel += self.GRAVITY

        if action == 1:
            self.vel = 0
            self.vel -= self.FLAP_POWER


        # Check whether bird passes the pipe or not
        for pipe in self.pipes:
            if pipe.centerx < self.bird_rect.centerx <= pipe.centerx + self.speed:
                reward = 1
                self.score += 1
                break

        # bird movement
        self.bird_rect.centery += self.vel

        # floor movement
        self.floorx -= 1
        if self.floorx < self.floor_limit:
            self.floorx = 0

        # pipes' movement
        for pipe in self.pipes:
            pipe.centerx -= self.speed

        # Update pipes
        if self.pipes[0].x <= -self.pipe_surface.get_width():
            self.pipes.extend(self._generate_pipes())

        # delete top and bottom pipes
        if self.pipes[0].x <= -self.pipe_surface.get_width():
            del self.pipes[0]
            del self.pipes[0]

        if (self.tick + 1) % 15 == 0:
            self.bird_index = (self.bird_index + 1) % 3
            self.bird, self.bird_rect = self.bird_animation()

        if self._is_collided():
            reward = -1
            terminal = True

        # draw
        self.screen.blit(self.background, (0, 0))

        for i, pipe in enumerate(self.pipes):
            if i % 2 == 0:
                flip_pipe = pygame.transform.flip(self.pipe_surface, False, True)
                self.screen.blit(flip_pipe, pipe)
            else:
                self.screen.blit(self.pipe_surface, pipe)

        self.screen.blit(self.floor, (self.floorx, self.floory))

        rotated_bird = self.rotate_bird()
        self.screen.blit(rotated_bird, self.bird_rect)

        pygame.display.update()
        screen = pygame.surfarray.array3d(pygame.display.get_surface())
        self.clock.tick(self.fps)

        return screen, reward, terminal


    def get_screen(self):
        return pygame.surfarray.array3d(pygame.display.get_surface())


    def reset(self):
        self.pipes.clear()
        self._init_()
        
    
    def quit(self):
        pygame.quit()

# %%
class DQN(nn.Module):
    def __init__(self, n_actions):
        super(DQN, self).__init__()
        # 84x84x4
        self.conv1 = nn.Conv2d(in_channels=4, out_channels=64, kernel_size=8, stride=4)
        self.bn1 = nn.BatchNorm2d(64)
        # 20x20x32
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        # 9x9x32
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(32)
        # 7x7x16
        self.fc1 = nn.Linear(7 * 7 * 32, 256)
        self.fc2 = nn.Linear(256, n_actions)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.fc1(x.view(x.size(0), -1)))
        return self.fc2(x)

# %%
# create env
env = Environment()

# if gpu is to be used
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)
# Out:
# '\nTransition = namedtuple(\'Transition\',\n                        (\'state\', \'action\', \'next_state\', \'reward\'))\n\n\nclass ReplayMemory(object):\n\n    def __init__(self, capacity):\n        self.capacity = capacity\n        self.memory = []\n        self.position = 0\n\n    def push(self, *args):\n        """Saves a transition."""\n        if len(self.memory) < self.capacity:\n            self.memory.append(None)\n        self.memory[self.position] = Transition(*args)\n        self.position = (self.position + 1) % self.capacity\n\n    def sample(self, batch_size):\n        return random.sample(self.memory, batch_size)\n\n    def __len__(self):\n        return len(self.memory)\n'

# %%
def init_weights(m):
    if type(m) == nn.Conv2d or type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0.01)

# %%
# steps_done = 0
# steps_done = 650000
# steps_done = 1465500
# steps_done = 1842549
steps_done = 2258029

def select_action(state):
    global steps_done
    sample = random.random()

    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)

    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.choices([0, 1], [0.5, 0.5])[0]]], device=device, dtype=torch.long)

# %%
resize = T.Compose([T.ToPILImage(),
                    T.Grayscale(),
                    T.CenterCrop((288, 288)),
                    T.Resize(84),
                    T.ToTensor()])

# hyperparameters
BATCH_SIZE = 64
GAMMA = 0.99 # discount factor
EPS_START = 1
EPS_END = 0.1
EPS_DECAY = 400000
TARGET_UPDATE = 10

n_actions = 2

# create networks
policy_net = DQN(n_actions).to(device)
target_net = DQN(n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = torch.optim.Adam(policy_net.parameters(), lr=1e-6)
criterion = nn.MSELoss()

memory = ReplayMemory(10000)

average_per_episode = []
score_per_episode = []
seq_length = []

num_episodes = int(1e5)
for i_episode in range(num_episodes):
    rewards = 0

    # Initialize the environment and state
    env.reset()

    init_screen = env.get_screen()

    init_screen = resize(init_screen)
    # (N, C, H, W): (1, 4, 84, 84)
    state = torch.cat(tuple(init_screen for _ in range(4))).unsqueeze(0).to(device)

    for t in count():
        # epsilon-greedy search (select action)
        action = select_action(state)
        screen, reward, done = env.step(action.item())
        rewards += reward

        screen = resize(screen).to(device)
        # next_state = resize(screen).unsqueeze(0).to(device)
        reward = torch.tensor([reward], device=device)

        next_state = torch.cat((state[0, 1:], screen)).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        if len(memory) >= 2 * BATCH_SIZE:
            for j in range(2):
                transitions = memory.sample(BATCH_SIZE)

                # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
                # detailed explanation). This converts batch-array of Transitions
                # to Transition of batch-arrays.
                batch = Transition(*zip(*transitions))

                # Compute a mask of non-final states and concatenate the batch elements
                # (a final state would've been the one after which simulation ended)
                non_final_mask = torch.tensor(tuple(map(lambda s: s != -1,
                                                        batch.reward)), device=device, dtype=torch.bool)
                
                non_final_next_states = torch.cat([s for s, r in zip(batch.next_state, batch.reward)
                                                if r != -1])

                state_batch = torch.cat(batch.state)
                action_batch = torch.cat(batch.action)
                reward_batch = torch.cat(batch.reward)

                # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
                # columns of actions taken. These are the actions which would've been taken
                # for each batch state according to policy_net
                state_action_values = policy_net(state_batch).gather(1, action_batch)

                # Compute V(s_{t+1}) for all next states.
                # Expected values of actions for non_final_next_states are computed based
                # on the "older" target_net; selecting their best reward with max(1)[0].
                # This is merged based on the mask, such that we'll have either the expected
                # state value or 0 in case the state was final.
                next_state_values = torch.zeros(BATCH_SIZE, device=device)
                next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()

                # Compute the expected Q values
                expected_state_action_values = (next_state_values * GAMMA) + reward_batch

                loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

                # Optimize the model
                optimizer.zero_grad()
                loss.backward()

                '''
                for param in policy_net.parameters():
                    param.grad.data.clamp_(-1, 1)
                '''

                optimizer.step()

        if done or t > 2000:
            average_per_episode.append(rewards/t)
            score_per_episode.append(env.score)
            seq_length.append(t)
            break
    
    print('Episode: {}, Score: {}, Reward: {}'.format(i_episode, env.score, rewards))

    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

    if i_episode % 2500 == 0:
        PATH = '/content/drive/MyDrive/Colab Notebooks/FlappyBird/state_dict_model_' + str(i_episode) + '.pt'
        torch.save(policy_net.state_dict(), PATH, _use_new_zipfile_serialization=False)
        

print('Complete')
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode: 10010, Score: 0, Reward: 2.2000000000000015
# Episode: 10011, Score: 0, Reward: 4.799999999999995
# Episode: 10012, Score: 0, Reward: 2.5000000000000018
# Episode: 10013, Score: 0, Reward: 2.1000000000000014
# Episode: 10014, Score: 0, Reward: 3.0000000000000018
# Episode: 10015, Score: 0, Reward: 2.7000000000000024
# Episode: 10016, Score: 0, Reward: 5.5999999999999925
# Episode: 10017, Score: 0, Reward: 3.1000000000000014
# Episode: 10018, Score: 0, Reward: 3.5999999999999996
# Episode: 10019, Score: 0, Reward: 2.900000000000002
# Episode: 10020, Score: 0, Reward: 2.2000000000000015
# Episode: 10021, Score: 0, Reward: 4.299999999999997
# Episode: 10022, Score: 0, Reward: 2.800000000000002
# Episode: 10023, Score: 0, Reward: 2.4000000000000017
# Episode: 10024, Score: 0, Reward: 2.1000000000000014
# Episode: 10025, Score: 0, Reward: 2.2000000000000015
# Episode: 10026, Score: 0, Reward: 2.900000000000002
# Episode: 10027, Score: 0, Reward: 3.200000000000001
# Episode: 10028, Score: 0, Reward: 3.0000000000000018
# Episode: 10029, Score: 0, Reward: 7.099999999999987
# Episode: 10030, Score: 0, Reward: 2.5000000000000018
# Episode: 10031, Score: 0, Reward: 2.5000000000000018
# Episode: 10032, Score: 0, Reward: 2.0000000000000013
# Episode: 10033, Score: 0, Reward: 4.299999999999997
# Episode: 10034, Score: 0, Reward: 3.799999999999999
# Episode: 10035, Score: 0, Reward: 2.5000000000000018
# Episode: 10036, Score: 0, Reward: 2.0000000000000013
# Episode: 10037, Score: 0, Reward: 2.7000000000000024
# Episode: 10038, Score: 0, Reward: 2.600000000000002
# Episode: 10039, Score: 0, Reward: 2.4000000000000017
# Episode: 10040, Score: 0, Reward: 4.299999999999997
# Episode: 10041, Score: 0, Reward: 2.800000000000002
# Episode: 10042, Score: 0, Reward: 2.3000000000000016
# Episode: 10043, Score: 0, Reward: 2.7000000000000024
# Episode: 10044, Score: 0, Reward: 2.4000000000000017
# Episode: 10045, Score: 0, Reward: 2.800000000000002
# Episode: 10046, Score: 0, Reward: 3.5999999999999996
# Episode: 10047, Score: 0, Reward: 3.0000000000000018
# Episode: 10048, Score: 0, Reward: 3.0000000000000018
# Episode: 10049, Score: 0, Reward: 3.1000000000000014
# Episode: 10050, Score: 0, Reward: 2.7000000000000024
# Episode: 10051, Score: 0, Reward: 3.1000000000000014
# Episode: 10052, Score: 0, Reward: 2.2000000000000015
# Episode: 10053, Score: 0, Reward: 2.7000000000000024
# Episode: 10054, Score: 0, Reward: 3.200000000000001
# Episode: 10055, Score: 0, Reward: 2.3000000000000016
# Episode: 10056, Score: 0, Reward: 2.5000000000000018
# Episode: 10057, Score: 0, Reward: 3.200000000000001
# Episode: 10058, Score: 0, Reward: 3.799999999999999
# Episode: 10059, Score: 0, Reward: 2.800000000000002
# Episode: 10060, Score: 0, Reward: 3.200000000000001
# Episode: 10061, Score: 0, Reward: 3.9999999999999982
# Episode: 10062, Score: 0, Reward: 3.4000000000000004
# Episode: 10063, Score: 0, Reward: 7.099999999999987
# Episode: 10064, Score: 0, Reward: 3.5
# Episode: 10065, Score: 0, Reward: 3.200000000000001
# Episode: 10066, Score: 0, Reward: 2.800000000000002
# Episode: 10067, Score: 0, Reward: 3.200000000000001
# Episode: 10068, Score: 0, Reward: 2.1000000000000014
# Episode: 10069, Score: 0, Reward: 2.1000000000000014
# Episode: 10070, Score: 0, Reward: 3.0000000000000018
# Episode: 10071, Score: 0, Reward: 2.3000000000000016
# Episode: 10072, Score: 0, Reward: 2.2000000000000015
# Episode: 10073, Score: 0, Reward: 2.7000000000000024
# Episode: 10074, Score: 0, Reward: 3.9999999999999982
# Episode: 10075, Score: 0, Reward: 2.1000000000000014
# Episode: 10076, Score: 0, Reward: 3.799999999999999
# Episode: 10077, Score: 0, Reward: 3.5
# Episode: 10078, Score: 0, Reward: 3.3000000000000007
# Episode: 10079, Score: 0, Reward: 4.599999999999996
# Episode: 10080, Score: 0, Reward: 2.1000000000000014
# Episode: 10081, Score: 0, Reward: 2.4000000000000017
# Episode: 10082, Score: 0, Reward: 2.1000000000000014
# Episode: 10083, Score: 0, Reward: 2.2000000000000015
# Episode: 10084, Score: 0, Reward: 2.1000000000000014
# Episode: 10085, Score: 0, Reward: 2.4000000000000017
# Episode: 10086, Score: 0, Reward: 3.9999999999999982
# Episode: 10087, Score: 0, Reward: 3.200000000000001
# Episode: 10088, Score: 0, Reward: 5.5999999999999925
# Episode: 10089, Score: 0, Reward: 2.3000000000000016
# Episode: 10090, Score: 0, Reward: 2.2000000000000015
# Episode: 10091, Score: 0, Reward: 2.0000000000000013
# Episode: 10092, Score: 0, Reward: 2.0000000000000013
# Episode: 10093, Score: 0, Reward: 3.4000000000000004
# Episode: 10094, Score: 0, Reward: 3.4000000000000004
# Episode: 10095, Score: 0, Reward: 3.1000000000000014
# Episode: 10096, Score: 0, Reward: 6.39999999999999
# Episode: 10097, Score: 0, Reward: 2.900000000000002
# Episode: 10098, Score: 0, Reward: 3.3000000000000007
# Episode: 10099, Score: 0, Reward: 2.2000000000000015
# Episode: 10100, Score: 0, Reward: 2.0000000000000013
# Episode: 10101, Score: 0, Reward: 3.6999999999999993
# Episode: 10102, Score: 0, Reward: 2.900000000000002
# Episode: 10103, Score: 0, Reward: 3.0000000000000018
# Episode: 10104, Score: 0, Reward: 3.3000000000000007
# Episode: 10105, Score: 0, Reward: 2.900000000000002
# Episode: 10106, Score: 0, Reward: 3.200000000000001
# Episode: 10107, Score: 0, Reward: 2.3000000000000016
# Episode: 10108, Score: 0, Reward: 2.3000000000000016
# Episode: 10109, Score: 0, Reward: 2.1000000000000014
# Episode: 10110, Score: 0, Reward: 2.5000000000000018
# Episode: 10111, Score: 0, Reward: 2.5000000000000018
# Episode: 10112, Score: 0, Reward: 3.5
# Episode: 10113, Score: 0, Reward: 2.800000000000002
# Episode: 10114, Score: 0, Reward: 7.099999999999987
# Episode: 10115, Score: 0, Reward: 2.3000000000000016
# Episode: 10116, Score: 0, Reward: 2.600000000000002
# Episode: 10117, Score: 0, Reward: 5.299999999999994
# Episode: 10118, Score: 0, Reward: 2.900000000000002
# Episode: 10119, Score: 0, Reward: 3.200000000000001
# Episode: 10120, Score: 0, Reward: 2.3000000000000016
# Episode: 10121, Score: 0, Reward: 2.2000000000000015
# Episode: 10122, Score: 0, Reward: 2.3000000000000016
# Episode: 10123, Score: 0, Reward: 2.1000000000000014
# Episode: 10124, Score: 0, Reward: 2.1000000000000014
# Episode: 10125, Score: 0, Reward: 3.3000000000000007
# Episode: 10126, Score: 0, Reward: 2.600000000000002
# Episode: 10127, Score: 0, Reward: 2.900000000000002
# Episode: 10128, Score: 0, Reward: 2.800000000000002
# Episode: 10129, Score: 0, Reward: 2.4000000000000017
# Episode: 10130, Score: 0, Reward: 5.299999999999994
# Episode: 10131, Score: 0, Reward: 2.5000000000000018
# Episode: 10132, Score: 0, Reward: 2.1000000000000014
# Episode: 10133, Score: 0, Reward: 2.3000000000000016
# Episode: 10134, Score: 0, Reward: 2.2000000000000015
# Episode: 10135, Score: 0, Reward: 2.7000000000000024
# Episode: 10136, Score: 0, Reward: 2.1000000000000014
# Episode: 10137, Score: 0, Reward: 2.5000000000000018
# Episode: 10138, Score: 0, Reward: 2.600000000000002
# Episode: 10139, Score: 0, Reward: 4.4999999999999964
# Episode: 10140, Score: 0, Reward: 3.200000000000001
# Episode: 10141, Score: 0, Reward: 3.0000000000000018
# Episode: 10142, Score: 0, Reward: 3.0000000000000018
# Episode: 10143, Score: 0, Reward: 2.7000000000000024
# Episode: 10144, Score: 0, Reward: 3.8999999999999986
# Episode: 10145, Score: 0, Reward: 3.5
# Episode: 10146, Score: 0, Reward: 2.7000000000000024
# Episode: 10147, Score: 0, Reward: 2.3000000000000016
# Episode: 10148, Score: 0, Reward: 2.3000000000000016
# Episode: 10149, Score: 0, Reward: 2.7000000000000024
# Episode: 10150, Score: 0, Reward: 2.7000000000000024
# Episode: 10151, Score: 0, Reward: 2.7000000000000024
# Episode: 10152, Score: 0, Reward: 2.7000000000000024
# Episode: 10153, Score: 0, Reward: 2.7000000000000024
# Episode: 10154, Score: 0, Reward: 2.1000000000000014
# Episode: 10155, Score: 0, Reward: 7.099999999999987
# Episode: 10156, Score: 0, Reward: 2.5000000000000018
# Episode: 10157, Score: 0, Reward: 2.3000000000000016
# Episode: 10158, Score: 0, Reward: 2.4000000000000017
# Episode: 10159, Score: 0, Reward: 2.2000000000000015
# Episode: 10160, Score: 0, Reward: 2.7000000000000024
# Episode: 10161, Score: 0, Reward: 6.799999999999987
# Episode: 10162, Score: 0, Reward: 2.7000000000000024
# Episode: 10163, Score: 0, Reward: 3.3000000000000007
# Episode: 10164, Score: 0, Reward: 2.2000000000000015
# Episode: 10165, Score: 0, Reward: 5.5999999999999925
# Episode: 10166, Score: 0, Reward: 2.3000000000000016
# Episode: 10167, Score: 0, Reward: 3.0000000000000018
# Episode: 10168, Score: 0, Reward: 3.200000000000001
# Episode: 10169, Score: 0, Reward: 3.1000000000000014
# Episode: 10170, Score: 0, Reward: 2.800000000000002
# Episode: 10171, Score: 0, Reward: 3.799999999999999
# Episode: 10172, Score: 0, Reward: 2.0000000000000013
# Episode: 10173, Score: 0, Reward: 3.1000000000000014
# Episode: 10174, Score: 0, Reward: 3.3000000000000007
# Episode: 10175, Score: 0, Reward: 4.099999999999998
# Episode: 10176, Score: 0, Reward: 3.200000000000001
# Episode: 10177, Score: 0, Reward: 2.800000000000002
# Episode: 10178, Score: 0, Reward: 3.0000000000000018
# Episode: 10179, Score: 0, Reward: 2.4000000000000017
# Episode: 10180, Score: 0, Reward: 2.2000000000000015
# Episode: 10181, Score: 0, Reward: 4.799999999999995
# Episode: 10182, Score: 0, Reward: 3.3000000000000007
# Episode: 10183, Score: 0, Reward: 3.0000000000000018
# Episode: 10184, Score: 0, Reward: 2.900000000000002
# Episode: 10185, Score: 0, Reward: 2.600000000000002
# Episode: 10186, Score: 0, Reward: 2.900000000000002
# Episode: 10187, Score: 0, Reward: 4.999999999999995
# Episode: 10188, Score: 0, Reward: 2.3000000000000016
# Episode: 10189, Score: 0, Reward: 4.699999999999996
# Episode: 10190, Score: 0, Reward: 4.4999999999999964
# Episode: 10191, Score: 0, Reward: 2.600000000000002
# Episode: 10192, Score: 0, Reward: 2.4000000000000017
# Episode: 10193, Score: 0, Reward: 2.4000000000000017
# Episode: 10194, Score: 0, Reward: 2.4000000000000017
# Episode: 10195, Score: 0, Reward: 2.3000000000000016
# Episode: 10196, Score: 0, Reward: 2.800000000000002
# Episode: 10197, Score: 0, Reward: 3.8999999999999986
# Episode: 10198, Score: 0, Reward: 5.5999999999999925
# Episode: 10199, Score: 0, Reward: 3.1000000000000014
# Episode: 10200, Score: 0, Reward: 2.600000000000002
# Episode: 10201, Score: 0, Reward: 2.5000000000000018
# Episode: 10202, Score: 0, Reward: 2.1000000000000014
# Episode: 10203, Score: 0, Reward: 2.800000000000002
# Episode: 10204, Score: 0, Reward: 3.1000000000000014
# Episode: 10205, Score: 0, Reward: 2.800000000000002
# Episode: 10206, Score: 0, Reward: 2.2000000000000015
# Episode: 10207, Score: 0, Reward: 2.1000000000000014
# Episode: 10208, Score: 0, Reward: 2.3000000000000016
# Episode: 10209, Score: 0, Reward: 2.1000000000000014
# Episode: 10210, Score: 0, Reward: 1.9000000000000015
# Episode: 10211, Score: 0, Reward: 2.1000000000000014
# Episode: 10212, Score: 0, Reward: 5.199999999999994
# Episode: 10213, Score: 0, Reward: 3.3000000000000007
# Episode: 10214, Score: 0, Reward: 2.0000000000000013
# Episode: 10215, Score: 0, Reward: 2.900000000000002
# Episode: 10216, Score: 0, Reward: 3.1000000000000014
# Episode: 10217, Score: 0, Reward: 2.4000000000000017
# Episode: 10218, Score: 0, Reward: 2.900000000000002
# Episode: 10219, Score: 0, Reward: 2.2000000000000015
# Episode: 10220, Score: 0, Reward: 2.900000000000002
# Episode: 10221, Score: 0, Reward: 2.7000000000000024
# Episode: 10222, Score: 0, Reward: 2.600000000000002
# Episode: 10223, Score: 0, Reward: 2.5000000000000018
# Episode: 10224, Score: 0, Reward: 2.3000000000000016
# Episode: 10225, Score: 0, Reward: 2.4000000000000017
# Episode: 10226, Score: 0, Reward: 2.7000000000000024
# Episode: 10227, Score: 0, Reward: 2.800000000000002
# Episode: 10228, Score: 0, Reward: 2.1000000000000014
# Episode: 10229, Score: 0, Reward: 6.699999999999989
# Episode: 10230, Score: 0, Reward: 2.7000000000000024
# Episode: 10231, Score: 0, Reward: 2.800000000000002
# Episode: 10232, Score: 0, Reward: 3.3000000000000007
# Episode: 10233, Score: 0, Reward: 6.29999999999999
# Episode: 10234, Score: 0, Reward: 3.6999999999999993
# Episode: 10235, Score: 0, Reward: 2.5000000000000018
# Episode: 10236, Score: 0, Reward: 3.200000000000001
# Episode: 10237, Score: 0, Reward: 2.900000000000002
# Episode: 10238, Score: 0, Reward: 2.3000000000000016
# Episode: 10239, Score: 0, Reward: 3.3000000000000007
# Episode: 10240, Score: 0, Reward: 2.4000000000000017
# Episode: 10241, Score: 0, Reward: 3.9999999999999982
# Episode: 10242, Score: 0, Reward: 4.799999999999995
# Episode: 10243, Score: 0, Reward: 3.200000000000001
# Episode: 10244, Score: 0, Reward: 4.099999999999998
# Episode: 10245, Score: 0, Reward: 3.200000000000001
# Episode: 10246, Score: 0, Reward: 3.0000000000000018
# Episode: 10247, Score: 0, Reward: 2.900000000000002
# Episode: 10248, Score: 0, Reward: 3.5999999999999996
# Episode: 10249, Score: 0, Reward: 3.799999999999999
# Episode: 10250, Score: 0, Reward: 2.3000000000000016
# Episode: 10251, Score: 0, Reward: 2.5000000000000018
# Episode: 10252, Score: 0, Reward: 2.600000000000002
# Episode: 10253, Score: 0, Reward: 2.0000000000000013
# Episode: 10254, Score: 0, Reward: 3.0000000000000018
# Episode: 10255, Score: 0, Reward: 3.3000000000000007
# Episode: 10256, Score: 0, Reward: 3.0000000000000018
# Episode: 10257, Score: 0, Reward: 3.5999999999999996
# Episode: 10258, Score: 0, Reward: 2.1000000000000014
# Episode: 10259, Score: 0, Reward: 2.2000000000000015
# Episode: 10260, Score: 0, Reward: 2.600000000000002
# Episode: 10261, Score: 0, Reward: 2.600000000000002
# Episode: 10262, Score: 0, Reward: 2.2000000000000015
# Episode: 10263, Score: 0, Reward: 3.200000000000001
# Episode: 10264, Score: 0, Reward: 2.800000000000002
# Episode: 10265, Score: 0, Reward: 3.799999999999999
# Episode: 10266, Score: 0, Reward: 2.900000000000002
# Episode: 10267, Score: 0, Reward: 2.1000000000000014
# Episode: 10268, Score: 0, Reward: 2.5000000000000018
# Episode: 10269, Score: 0, Reward: 3.3000000000000007
# Episode: 10270, Score: 0, Reward: 2.4000000000000017
# Episode: 10271, Score: 0, Reward: 2.7000000000000024
# Episode: 10272, Score: 0, Reward: 5.399999999999993
# Episode: 10273, Score: 0, Reward: 3.1000000000000014
# Episode: 10274, Score: 0, Reward: 6.39999999999999
# Episode: 10275, Score: 0, Reward: 3.799999999999999
# Episode: 10276, Score: 0, Reward: 3.799999999999999
# Episode: 10277, Score: 0, Reward: 2.4000000000000017
# Episode: 10278, Score: 0, Reward: 2.4000000000000017
# Episode: 10279, Score: 0, Reward: 2.5000000000000018
# Episode: 10280, Score: 0, Reward: 2.3000000000000016
# Episode: 10281, Score: 0, Reward: 2.4000000000000017
# Episode: 10282, Score: 0, Reward: 2.5000000000000018
# Episode: 10283, Score: 0, Reward: 2.3000000000000016
# Episode: 10284, Score: 0, Reward: 2.2000000000000015
# Episode: 10285, Score: 0, Reward: 3.9999999999999982
# Episode: 10286, Score: 0, Reward: 3.6999999999999993
# Episode: 10287, Score: 0, Reward: 2.600000000000002
# Episode: 10288, Score: 0, Reward: 2.800000000000002
# Episode: 10289, Score: 0, Reward: 2.0000000000000013
# Episode: 10290, Score: 0, Reward: 2.800000000000002
# Episode: 10291, Score: 0, Reward: 2.800000000000002
# Episode: 10292, Score: 0, Reward: 3.5
# Episode: 10293, Score: 0, Reward: 3.0000000000000018
# Episode: 10294, Score: 0, Reward: 2.5000000000000018
# Episode: 10295, Score: 0, Reward: 5.199999999999994
# Episode: 10296, Score: 0, Reward: 2.7000000000000024
# Episode: 10297, Score: 0, Reward: 2.600000000000002
# Episode: 10298, Score: 0, Reward: 3.0000000000000018
# Episode: 10299, Score: 0, Reward: 3.8999999999999986
# Episode: 10300, Score: 0, Reward: 5.499999999999993
# Episode: 10301, Score: 0, Reward: 2.7000000000000024
# Episode: 10302, Score: 0, Reward: 2.1000000000000014
# Episode: 10303, Score: 0, Reward: 2.900000000000002
# Episode: 10304, Score: 0, Reward: 2.900000000000002
# Episode: 10305, Score: 0, Reward: 3.5999999999999996
# Episode: 10306, Score: 0, Reward: 2.3000000000000016
# Episode: 10307, Score: 0, Reward: 3.0000000000000018
# Episode: 10308, Score: 0, Reward: 3.3000000000000007
# Episode: 10309, Score: 0, Reward: 3.200000000000001
# Episode: 10310, Score: 0, Reward: 3.8999999999999986
# Episode: 10311, Score: 0, Reward: 2.600000000000002
# Episode: 10312, Score: 0, Reward: 3.1000000000000014
# Episode: 10313, Score: 0, Reward: 3.4000000000000004
# Episode: 10314, Score: 0, Reward: 2.0000000000000013
# Episode: 10315, Score: 0, Reward: 2.2000000000000015
# Episode: 10316, Score: 0, Reward: 2.600000000000002
# Episode: 10317, Score: 0, Reward: 4.1999999999999975
# Episode: 10318, Score: 0, Reward: 2.900000000000002
# Episode: 10319, Score: 0, Reward: 2.4000000000000017
# Episode: 10320, Score: 0, Reward: 5.399999999999993
# Episode: 10321, Score: 0, Reward: 2.7000000000000024
# Episode: 10322, Score: 0, Reward: 3.5999999999999996
# Episode: 10323, Score: 0, Reward: 2.4000000000000017
# Episode: 10324, Score: 0, Reward: 3.0000000000000018
# Episode: 10325, Score: 0, Reward: 2.5000000000000018
# Episode: 10326, Score: 0, Reward: 2.2000000000000015
# Episode: 10327, Score: 0, Reward: 2.3000000000000016
# Episode: 10328, Score: 0, Reward: 2.2000000000000015
# Episode: 10329, Score: 0, Reward: 2.3000000000000016
# Episode: 10330, Score: 0, Reward: 7.099999999999987
# Episode: 10331, Score: 0, Reward: 2.3000000000000016
# Episode: 10332, Score: 0, Reward: 2.800000000000002
# Episode: 10333, Score: 0, Reward: 2.600000000000002
# Episode: 10334, Score: 0, Reward: 2.5000000000000018
# Episode: 10335, Score: 0, Reward: 2.4000000000000017
# Episode: 10336, Score: 0, Reward: 3.0000000000000018
# Episode: 10337, Score: 0, Reward: 3.4000000000000004
# Episode: 10338, Score: 0, Reward: 2.800000000000002
# Episode: 10339, Score: 0, Reward: 3.4000000000000004
# Episode: 10340, Score: 0, Reward: 3.200000000000001
# Episode: 10341, Score: 0, Reward: 2.5000000000000018
# Episode: 10342, Score: 0, Reward: 2.2000000000000015
# Episode: 10343, Score: 0, Reward: 2.0000000000000013
# Episode: 10344, Score: 0, Reward: 3.1000000000000014
# Episode: 10345, Score: 0, Reward: 2.2000000000000015
# Episode: 10346, Score: 0, Reward: 3.0000000000000018
# Episode: 10347, Score: 0, Reward: 3.3000000000000007
# Episode: 10348, Score: 0, Reward: 5.499999999999993
# Episode: 10349, Score: 0, Reward: 6.799999999999987
# Episode: 10350, Score: 0, Reward: 2.3000000000000016
# Episode: 10351, Score: 0, Reward: 2.7000000000000024
# Episode: 10352, Score: 0, Reward: 3.0000000000000018
# Episode: 10353, Score: 0, Reward: 2.900000000000002
# Episode: 10354, Score: 0, Reward: 2.1000000000000014
# Episode: 10355, Score: 0, Reward: 2.1000000000000014
# Episode: 10356, Score: 0, Reward: 2.800000000000002
# Episode: 10357, Score: 0, Reward: 2.7000000000000024
# Episode: 10358, Score: 0, Reward: 3.1000000000000014
# Episode: 10359, Score: 0, Reward: 2.2000000000000015
# Episode: 10360, Score: 0, Reward: 2.1000000000000014
# Episode: 10361, Score: 0, Reward: 2.1000000000000014
# Episode: 10362, Score: 0, Reward: 7.099999999999987
# Episode: 10363, Score: 0, Reward: 3.3000000000000007
# Episode: 10364, Score: 0, Reward: 7.099999999999987
# Episode: 10365, Score: 0, Reward: 2.900000000000002
# Episode: 10366, Score: 0, Reward: 2.600000000000002
# Episode: 10367, Score: 0, Reward: 4.099999999999998
# Episode: 10368, Score: 0, Reward: 3.0000000000000018
# Episode: 10369, Score: 0, Reward: 4.599999999999996
# Episode: 10370, Score: 0, Reward: 2.2000000000000015
# Episode: 10371, Score: 0, Reward: 2.4000000000000017
# Episode: 10372, Score: 0, Reward: 2.7000000000000024
# Episode: 10373, Score: 0, Reward: 4.299999999999997
# Episode: 10374, Score: 0, Reward: 3.3000000000000007
# Episode: 10375, Score: 0, Reward: 2.5000000000000018
# Episode: 10376, Score: 0, Reward: 3.5
# Episode: 10377, Score: 0, Reward: 6.29999999999999
# Episode: 10378, Score: 0, Reward: 2.600000000000002
# Episode: 10379, Score: 0, Reward: 2.2000000000000015
# Episode: 10380, Score: 0, Reward: 2.600000000000002
# Episode: 10381, Score: 0, Reward: 2.1000000000000014
# Episode: 10382, Score: 0, Reward: 4.399999999999997
# Episode: 10383, Score: 0, Reward: 2.5000000000000018
# Episode: 10384, Score: 0, Reward: 3.200000000000001
# Episode: 10385, Score: 0, Reward: 2.1000000000000014
# Episode: 10386, Score: 0, Reward: 3.4000000000000004
# Episode: 10387, Score: 0, Reward: 3.8999999999999986
# Episode: 10388, Score: 0, Reward: 2.900000000000002
# Episode: 10389, Score: 0, Reward: 2.7000000000000024
# Episode: 10390, Score: 0, Reward: 2.600000000000002
# Episode: 10391, Score: 0, Reward: 2.7000000000000024
# Episode: 10392, Score: 0, Reward: 3.4000000000000004
# Episode: 10393, Score: 0, Reward: 2.800000000000002
# Episode: 10394, Score: 0, Reward: 2.4000000000000017
# Episode: 10395, Score: 0, Reward: 2.2000000000000015
# Episode: 10396, Score: 0, Reward: 2.1000000000000014
# Episode: 10397, Score: 0, Reward: 2.4000000000000017
# Episode: 10398, Score: 0, Reward: 2.3000000000000016
# Episode: 10399, Score: 0, Reward: 2.1000000000000014
# Episode: 10400, Score: 0, Reward: 2.2000000000000015
# Episode: 10401, Score: 0, Reward: 4.1999999999999975
# Episode: 10402, Score: 0, Reward: 3.5999999999999996
# Episode: 10403, Score: 0, Reward: 2.600000000000002
# Episode: 10404, Score: 0, Reward: 2.2000000000000015
# Episode: 10405, Score: 0, Reward: 3.200000000000001
# Episode: 10406, Score: 0, Reward: 2.1000000000000014
# Episode: 10407, Score: 0, Reward: 2.3000000000000016
# Episode: 10408, Score: 0, Reward: 3.5
# Episode: 10409, Score: 0, Reward: 2.1000000000000014
# Episode: 10410, Score: 0, Reward: 3.6999999999999993
# Episode: 10411, Score: 0, Reward: 2.5000000000000018
# Episode: 10412, Score: 0, Reward: 3.6999999999999993
# Episode: 10413, Score: 0, Reward: 2.4000000000000017
# Episode: 10414, Score: 0, Reward: 2.7000000000000024
# Episode: 10415, Score: 0, Reward: 3.1000000000000014
# Episode: 10416, Score: 0, Reward: 2.900000000000002
# Episode: 10417, Score: 0, Reward: 3.3000000000000007
# Episode: 10418, Score: 0, Reward: 2.0000000000000013
# Episode: 10419, Score: 0, Reward: 2.5000000000000018
# Episode: 10420, Score: 0, Reward: 2.7000000000000024
# Episode: 10421, Score: 0, Reward: 7.099999999999987
# Episode: 10422, Score: 0, Reward: 2.600000000000002
# Episode: 10423, Score: 0, Reward: 3.8999999999999986
# Episode: 10424, Score: 0, Reward: 3.5999999999999996
# Episode: 10425, Score: 0, Reward: 2.3000000000000016
# Episode: 10426, Score: 0, Reward: 3.8999999999999986
# Episode: 10427, Score: 0, Reward: 3.0000000000000018
# Episode: 10428, Score: 0, Reward: 3.6999999999999993
# Episode: 10429, Score: 0, Reward: 4.799999999999995
# Episode: 10430, Score: 0, Reward: 3.200000000000001
# Episode: 10431, Score: 0, Reward: 2.7000000000000024
# Episode: 10432, Score: 0, Reward: 3.1000000000000014
# Episode: 10433, Score: 0, Reward: 2.900000000000002
# Episode: 10434, Score: 0, Reward: 2.900000000000002
# Episode: 10435, Score: 0, Reward: 3.200000000000001
# Episode: 10436, Score: 0, Reward: 3.799999999999999
# Episode: 10437, Score: 0, Reward: 2.5000000000000018
# Episode: 10438, Score: 0, Reward: 3.200000000000001
# Episode: 10439, Score: 0, Reward: 2.3000000000000016
# Episode: 10440, Score: 0, Reward: 2.2000000000000015
# Episode: 10441, Score: 0, Reward: 4.399999999999997
# Episode: 10442, Score: 0, Reward: 3.5
# Episode: 10443, Score: 0, Reward: 4.4999999999999964
# Episode: 10444, Score: 0, Reward: 4.1999999999999975
# Episode: 10445, Score: 0, Reward: 3.799999999999999
# Episode: 10446, Score: 0, Reward: 3.0000000000000018
# Episode: 10447, Score: 0, Reward: 2.4000000000000017
# Episode: 10448, Score: 0, Reward: 2.1000000000000014
# Episode: 10449, Score: 0, Reward: 2.2000000000000015
# Episode: 10450, Score: 0, Reward: 2.3000000000000016
# Episode: 10451, Score: 0, Reward: 2.800000000000002
# Episode: 10452, Score: 0, Reward: 3.0000000000000018
# Episode: 10453, Score: 0, Reward: 2.5000000000000018
# Episode: 10454, Score: 0, Reward: 2.7000000000000024
# Episode: 10455, Score: 0, Reward: 2.4000000000000017
# Episode: 10456, Score: 0, Reward: 2.2000000000000015
# Episode: 10457, Score: 0, Reward: 2.7000000000000024
# Episode: 10458, Score: 0, Reward: 2.3000000000000016
# Episode: 10459, Score: 0, Reward: 2.4000000000000017
# Episode: 10460, Score: 0, Reward: 3.200000000000001
# Episode: 10461, Score: 0, Reward: 2.4000000000000017
# Episode: 10462, Score: 0, Reward: 2.0000000000000013
# Episode: 10463, Score: 0, Reward: 2.4000000000000017
# Episode: 10464, Score: 0, Reward: 2.4000000000000017
# Episode: 10465, Score: 0, Reward: 2.4000000000000017
# Episode: 10466, Score: 0, Reward: 3.1000000000000014
# Episode: 10467, Score: 0, Reward: 2.7000000000000024
# Episode: 10468, Score: 0, Reward: 2.800000000000002
# Episode: 10469, Score: 0, Reward: 4.4999999999999964
# Episode: 10470, Score: 0, Reward: 2.4000000000000017
# Episode: 10471, Score: 0, Reward: 2.4000000000000017
# Episode: 10472, Score: 0, Reward: 2.3000000000000016
# Episode: 10473, Score: 0, Reward: 2.5000000000000018
# Episode: 10474, Score: 0, Reward: 3.200000000000001
# Episode: 10475, Score: 0, Reward: 5.099999999999994
# Episode: 10476, Score: 0, Reward: 2.7000000000000024
# Episode: 10477, Score: 0, Reward: 3.0000000000000018
# Episode: 10478, Score: 0, Reward: 2.1000000000000014
# Episode: 10479, Score: 0, Reward: 3.6999999999999993
# Episode: 10480, Score: 0, Reward: 2.800000000000002
# Episode: 10481, Score: 0, Reward: 4.299999999999997
# Episode: 10482, Score: 0, Reward: 2.5000000000000018
# Episode: 10483, Score: 0, Reward: 2.3000000000000016
# Episode: 10484, Score: 0, Reward: 2.5000000000000018
# Episode: 10485, Score: 0, Reward: 2.600000000000002
# Episode: 10486, Score: 0, Reward: 2.3000000000000016
# Episode: 10487, Score: 0, Reward: 3.200000000000001
# Episode: 10488, Score: 0, Reward: 2.4000000000000017
# Episode: 10489, Score: 0, Reward: 2.600000000000002
# Episode: 10490, Score: 0, Reward: 3.5
# Episode: 10491, Score: 0, Reward: 2.800000000000002
# Episode: 10492, Score: 0, Reward: 2.5000000000000018
# Episode: 10493, Score: 0, Reward: 2.4000000000000017
# Episode: 10494, Score: 0, Reward: 2.2000000000000015
# Episode: 10495, Score: 0, Reward: 2.4000000000000017
# Episode: 10496, Score: 0, Reward: 2.5000000000000018
# Episode: 10497, Score: 0, Reward: 2.3000000000000016
# Episode: 10498, Score: 0, Reward: 2.2000000000000015
# Episode: 10499, Score: 0, Reward: 2.7000000000000024
# Episode: 10500, Score: 0, Reward: 4.299999999999997
# Episode: 10501, Score: 0, Reward: 3.4000000000000004
# Episode: 10502, Score: 0, Reward: 2.900000000000002
# Episode: 10503, Score: 0, Reward: 3.799999999999999
# Episode: 10504, Score: 0, Reward: 2.900000000000002
# Episode: 10505, Score: 0, Reward: 3.5
# Episode: 10506, Score: 0, Reward: 3.5
# Episode: 10507, Score: 0, Reward: 4.799999999999995
# Episode: 10508, Score: 0, Reward: 2.900000000000002
# Episode: 10509, Score: 0, Reward: 3.1000000000000014
# Episode: 10510, Score: 0, Reward: 2.5000000000000018
# Episode: 10511, Score: 0, Reward: 4.299999999999997
# Episode: 10512, Score: 0, Reward: 2.4000000000000017
# Episode: 10513, Score: 0, Reward: 2.7000000000000024
# Episode: 10514, Score: 0, Reward: 3.5
# Episode: 10515, Score: 0, Reward: 2.2000000000000015
# Episode: 10516, Score: 0, Reward: 2.900000000000002
# Episode: 10517, Score: 0, Reward: 3.1000000000000014
# Episode: 10518, Score: 0, Reward: 3.9999999999999982
# Episode: 10519, Score: 0, Reward: 3.4000000000000004
# Episode: 10520, Score: 0, Reward: 5.999999999999991
# Episode: 10521, Score: 0, Reward: 2.4000000000000017
# Episode: 10522, Score: 0, Reward: 2.7000000000000024
# Episode: 10523, Score: 0, Reward: 2.1000000000000014
# Episode: 10524, Score: 0, Reward: 2.4000000000000017
# Episode: 10525, Score: 0, Reward: 2.600000000000002
# Episode: 10526, Score: 0, Reward: 2.3000000000000016
# Episode: 10527, Score: 0, Reward: 2.600000000000002
# Episode: 10528, Score: 0, Reward: 3.200000000000001
# Episode: 10529, Score: 0, Reward: 2.3000000000000016
# Episode: 10530, Score: 0, Reward: 3.0000000000000018
# Episode: 10531, Score: 0, Reward: 2.1000000000000014
# Episode: 10532, Score: 0, Reward: 3.5
# Episode: 10533, Score: 0, Reward: 2.7000000000000024
# Episode: 10534, Score: 0, Reward: 5.699999999999992
# Episode: 10535, Score: 0, Reward: 2.3000000000000016
# Episode: 10536, Score: 0, Reward: 3.200000000000001
# Episode: 10537, Score: 0, Reward: 2.900000000000002
# Episode: 10538, Score: 0, Reward: 2.2000000000000015
# Episode: 10539, Score: 0, Reward: 3.4000000000000004
# Episode: 10540, Score: 0, Reward: 2.600000000000002
# Episode: 10541, Score: 0, Reward: 2.5000000000000018
# Episode: 10542, Score: 0, Reward: 2.800000000000002
# Episode: 10543, Score: 0, Reward: 2.1000000000000014
# Episode: 10544, Score: 0, Reward: 3.6999999999999993
# Episode: 10545, Score: 0, Reward: 4.399999999999997
# Episode: 10546, Score: 0, Reward: 3.0000000000000018
# Episode: 10547, Score: 0, Reward: 2.0000000000000013
# Episode: 10548, Score: 0, Reward: 7.099999999999987
# Episode: 10549, Score: 0, Reward: 4.099999999999998
# Episode: 10550, Score: 0, Reward: 4.099999999999998
# Episode: 10551, Score: 0, Reward: 2.800000000000002
# Episode: 10552, Score: 0, Reward: 2.600000000000002
# Episode: 10553, Score: 0, Reward: 3.3000000000000007
# Episode: 10554, Score: 0, Reward: 3.0000000000000018
# Episode: 10555, Score: 0, Reward: 3.5999999999999996
# Episode: 10556, Score: 0, Reward: 2.800000000000002
# Episode: 10557, Score: 0, Reward: 2.5000000000000018
# Episode: 10558, Score: 0, Reward: 2.5000000000000018
# Episode: 10559, Score: 0, Reward: 2.4000000000000017
# Episode: 10560, Score: 0, Reward: 2.900000000000002
# Episode: 10561, Score: 0, Reward: 3.200000000000001
# Episode: 10562, Score: 0, Reward: 3.200000000000001
# Episode: 10563, Score: 0, Reward: 4.799999999999995
# Episode: 10564, Score: 0, Reward: 2.900000000000002
# Episode: 10565, Score: 0, Reward: 3.9999999999999982
# Episode: 10566, Score: 0, Reward: 2.600000000000002
# Episode: 10567, Score: 0, Reward: 3.3000000000000007
# Episode: 10568, Score: 0, Reward: 2.1000000000000014
# Episode: 10569, Score: 0, Reward: 2.1000000000000014
# Episode: 10570, Score: 0, Reward: 3.1000000000000014
# Episode: 10571, Score: 0, Reward: 2.2000000000000015
# Episode: 10572, Score: 0, Reward: 3.8999999999999986
# Episode: 10573, Score: 0, Reward: 2.5000000000000018
# Episode: 10574, Score: 0, Reward: 3.799999999999999
# Episode: 10575, Score: 0, Reward: 5.099999999999994
# Episode: 10576, Score: 0, Reward: 6.39999999999999
# Episode: 10577, Score: 0, Reward: 2.7000000000000024
# Episode: 10578, Score: 0, Reward: 2.7000000000000024
# Episode: 10579, Score: 0, Reward: 3.1000000000000014
# Episode: 10580, Score: 0, Reward: 2.800000000000002
# Episode: 10581, Score: 0, Reward: 3.3000000000000007
# Episode: 10582, Score: 0, Reward: 3.3000000000000007
# Episode: 10583, Score: 0, Reward: 2.2000000000000015
# Episode: 10584, Score: 0, Reward: 2.600000000000002
# Episode: 10585, Score: 0, Reward: 2.900000000000002
# Episode: 10586, Score: 0, Reward: 2.600000000000002
# Episode: 10587, Score: 0, Reward: 2.3000000000000016
# Episode: 10588, Score: 0, Reward: 2.4000000000000017
# Episode: 10589, Score: 0, Reward: 3.200000000000001
# Episode: 10590, Score: 0, Reward: 2.600000000000002
# Episode: 10591, Score: 0, Reward: 3.0000000000000018
# Episode: 10592, Score: 0, Reward: 3.4000000000000004
# Episode: 10593, Score: 0, Reward: 2.3000000000000016
# Episode: 10594, Score: 0, Reward: 2.2000000000000015
# Episode: 10595, Score: 0, Reward: 2.2000000000000015
# Episode: 10596, Score: 0, Reward: 2.2000000000000015
# Episode: 10597, Score: 0, Reward: 2.3000000000000016
# Episode: 10598, Score: 0, Reward: 3.5999999999999996
# Episode: 10599, Score: 0, Reward: 3.0000000000000018
# Episode: 10600, Score: 0, Reward: 3.3000000000000007
# Episode: 10601, Score: 0, Reward: 3.5
# Episode: 10602, Score: 0, Reward: 2.3000000000000016
# Episode: 10603, Score: 0, Reward: 2.4000000000000017
# Episode: 10604, Score: 0, Reward: 3.5999999999999996
# Episode: 10605, Score: 0, Reward: 2.600000000000002
# Episode: 10606, Score: 0, Reward: 4.999999999999995
# Episode: 10607, Score: 0, Reward: 3.8999999999999986
# Episode: 10608, Score: 0, Reward: 3.8999999999999986
# Episode: 10609, Score: 0, Reward: 2.3000000000000016
# Episode: 10610, Score: 0, Reward: 2.3000000000000016
# Episode: 10611, Score: 0, Reward: 2.3000000000000016
# Episode: 10612, Score: 0, Reward: 3.1000000000000014
# Episode: 10613, Score: 0, Reward: 2.5000000000000018
# Episode: 10614, Score: 0, Reward: 3.200000000000001
# Episode: 10615, Score: 0, Reward: 2.2000000000000015
# Episode: 10616, Score: 0, Reward: 2.2000000000000015
# Episode: 10617, Score: 0, Reward: 3.4000000000000004
# Episode: 10618, Score: 0, Reward: 4.1999999999999975
# Episode: 10619, Score: 0, Reward: 2.600000000000002
# Episode: 10620, Score: 0, Reward: 3.0000000000000018
# Episode: 10621, Score: 0, Reward: 5.8999999999999915
# Episode: 10622, Score: 0, Reward: 3.5999999999999996
# Episode: 10623, Score: 0, Reward: 2.3000000000000016
# Episode: 10624, Score: 0, Reward: 2.5000000000000018
# Episode: 10625, Score: 0, Reward: 3.5
# Episode: 10626, Score: 0, Reward: 2.600000000000002
# Episode: 10627, Score: 0, Reward: 2.3000000000000016
# Episode: 10628, Score: 0, Reward: 2.600000000000002
# Episode: 10629, Score: 0, Reward: 3.4000000000000004
# Episode: 10630, Score: 0, Reward: 2.800000000000002
# Episode: 10631, Score: 0, Reward: 5.099999999999994
# Episode: 10632, Score: 0, Reward: 2.600000000000002
# Episode: 10633, Score: 0, Reward: 2.2000000000000015
# Episode: 10634, Score: 0, Reward: 2.3000000000000016
# Episode: 10635, Score: 0, Reward: 3.200000000000001
# Episode: 10636, Score: 0, Reward: 3.1000000000000014
# Episode: 10637, Score: 0, Reward: 2.4000000000000017
# Episode: 10638, Score: 0, Reward: 2.7000000000000024
# Episode: 10639, Score: 0, Reward: 3.9999999999999982
# Episode: 10640, Score: 0, Reward: 3.1000000000000014
# Episode: 10641, Score: 0, Reward: 2.900000000000002
# Episode: 10642, Score: 0, Reward: 3.200000000000001
# Episode: 10643, Score: 0, Reward: 2.600000000000002
# Episode: 10644, Score: 0, Reward: 2.7000000000000024
# Episode: 10645, Score: 0, Reward: 3.1000000000000014
# Episode: 10646, Score: 0, Reward: 2.4000000000000017
# Episode: 10647, Score: 0, Reward: 2.7000000000000024
# Episode: 10648, Score: 0, Reward: 2.1000000000000014
# Episode: 10649, Score: 0, Reward: 2.900000000000002
# Episode: 10650, Score: 0, Reward: 6.49999999999999
# Episode: 10651, Score: 0, Reward: 6.49999999999999
# Episode: 10652, Score: 0, Reward: 2.5000000000000018
# Episode: 10653, Score: 0, Reward: 2.5000000000000018
# Episode: 10654, Score: 0, Reward: 3.0000000000000018
# Episode: 10655, Score: 0, Reward: 2.1000000000000014
# Episode: 10656, Score: 0, Reward: 2.3000000000000016
# Episode: 10657, Score: 0, Reward: 2.3000000000000016
# Episode: 10658, Score: 0, Reward: 2.7000000000000024
# Episode: 10659, Score: 0, Reward: 4.299999999999997
# Episode: 10660, Score: 0, Reward: 2.600000000000002
# Episode: 10661, Score: 0, Reward: 2.5000000000000018
# Episode: 10662, Score: 0, Reward: 3.1000000000000014
# Episode: 10663, Score: 0, Reward: 2.5000000000000018
# Episode: 10664, Score: 0, Reward: 2.4000000000000017
# Episode: 10665, Score: 0, Reward: 7.099999999999987
# Episode: 10666, Score: 0, Reward: 3.200000000000001
# Episode: 10667, Score: 0, Reward: 3.1000000000000014
# Episode: 10668, Score: 0, Reward: 2.4000000000000017
# Episode: 10669, Score: 0, Reward: 2.7000000000000024
# Episode: 10670, Score: 0, Reward: 4.899999999999995
# Episode: 10671, Score: 0, Reward: 2.3000000000000016
# Episode: 10672, Score: 0, Reward: 2.1000000000000014
# Episode: 10673, Score: 0, Reward: 2.800000000000002
# Episode: 10674, Score: 0, Reward: 2.5000000000000018
# Episode: 10675, Score: 0, Reward: 2.4000000000000017
# Episode: 10676, Score: 0, Reward: 2.600000000000002
# Episode: 10677, Score: 0, Reward: 5.699999999999992
# Episode: 10678, Score: 0, Reward: 2.900000000000002
# Episode: 10679, Score: 0, Reward: 3.4000000000000004
# Episode: 10680, Score: 0, Reward: 3.0000000000000018
# Episode: 10681, Score: 0, Reward: 2.1000000000000014
# Episode: 10682, Score: 0, Reward: 2.2000000000000015
# Episode: 10683, Score: 0, Reward: 2.1000000000000014
# Episode: 10684, Score: 0, Reward: 3.200000000000001
# Episode: 10685, Score: 0, Reward: 3.4000000000000004
# Episode: 10686, Score: 0, Reward: 3.0000000000000018
# Episode: 10687, Score: 0, Reward: 2.2000000000000015
# Episode: 10688, Score: 0, Reward: 3.6999999999999993
# Episode: 10689, Score: 0, Reward: 2.5000000000000018
# Episode: 10690, Score: 0, Reward: 3.3000000000000007
# Episode: 10691, Score: 0, Reward: 2.1000000000000014
# Episode: 10692, Score: 0, Reward: 2.1000000000000014
# Episode: 10693, Score: 0, Reward: 2.4000000000000017
# Episode: 10694, Score: 0, Reward: 2.3000000000000016
# Episode: 10695, Score: 0, Reward: 2.0000000000000013
# Episode: 10696, Score: 0, Reward: 3.5
# Episode: 10697, Score: 0, Reward: 3.1000000000000014
# Episode: 10698, Score: 0, Reward: 3.4000000000000004
# Episode: 10699, Score: 0, Reward: 4.699999999999996
# Episode: 10700, Score: 0, Reward: 2.7000000000000024
# Episode: 10701, Score: 0, Reward: 3.1000000000000014
# Episode: 10702, Score: 0, Reward: 3.1000000000000014
# Episode: 10703, Score: 0, Reward: 3.1000000000000014
# Episode: 10704, Score: 0, Reward: 2.600000000000002
# Episode: 10705, Score: 0, Reward: 3.1000000000000014
# Episode: 10706, Score: 0, Reward: 3.200000000000001
# Episode: 10707, Score: 0, Reward: 3.1000000000000014
# Episode: 10708, Score: 0, Reward: 2.3000000000000016
# Episode: 10709, Score: 0, Reward: 2.2000000000000015
# Episode: 10710, Score: 0, Reward: 3.200000000000001
# Episode: 10711, Score: 0, Reward: 5.099999999999994
# Episode: 10712, Score: 0, Reward: 2.3000000000000016
# Episode: 10713, Score: 0, Reward: 3.799999999999999
# Episode: 10714, Score: 0, Reward: 2.7000000000000024
# Episode: 10715, Score: 0, Reward: 3.4000000000000004
# Episode: 10716, Score: 0, Reward: 3.799999999999999
# Episode: 10717, Score: 0, Reward: 3.4000000000000004
# Episode: 10718, Score: 0, Reward: 3.4000000000000004
# Episode: 10719, Score: 0, Reward: 2.4000000000000017
# Episode: 10720, Score: 0, Reward: 2.1000000000000014
# Episode: 10721, Score: 0, Reward: 3.9999999999999982
# Episode: 10722, Score: 0, Reward: 3.200000000000001
# Episode: 10723, Score: 0, Reward: 3.0000000000000018
# Episode: 10724, Score: 0, Reward: 2.2000000000000015
# Episode: 10725, Score: 0, Reward: 2.600000000000002
# Episode: 10726, Score: 0, Reward: 2.600000000000002
# Episode: 10727, Score: 0, Reward: 3.0000000000000018
# Episode: 10728, Score: 0, Reward: 3.4000000000000004
# Episode: 10729, Score: 0, Reward: 2.7000000000000024
# Episode: 10730, Score: 0, Reward: 3.0000000000000018
# Episode: 10731, Score: 0, Reward: 2.2000000000000015
# Episode: 10732, Score: 0, Reward: 2.2000000000000015
# Episode: 10733, Score: 0, Reward: 2.3000000000000016
# Episode: 10734, Score: 0, Reward: 2.600000000000002
# Episode: 10735, Score: 0, Reward: 2.1000000000000014
# Episode: 10736, Score: 0, Reward: 3.1000000000000014
# Episode: 10737, Score: 0, Reward: 2.3000000000000016
# Episode: 10738, Score: 0, Reward: 2.600000000000002
# Episode: 10739, Score: 0, Reward: 2.800000000000002
# Episode: 10740, Score: 0, Reward: 2.3000000000000016
# Episode: 10741, Score: 0, Reward: 2.800000000000002
# Episode: 10742, Score: 0, Reward: 2.4000000000000017
# Episode: 10743, Score: 0, Reward: 2.4000000000000017
# Episode: 10744, Score: 0, Reward: 2.3000000000000016
# Episode: 10745, Score: 0, Reward: 2.2000000000000015
# Episode: 10746, Score: 0, Reward: 2.3000000000000016
# Episode: 10747, Score: 0, Reward: 2.5000000000000018
# Episode: 10748, Score: 0, Reward: 2.3000000000000016
# Episode: 10749, Score: 0, Reward: 3.5
# Episode: 10750, Score: 0, Reward: 2.900000000000002
# Episode: 10751, Score: 0, Reward: 2.5000000000000018
# Episode: 10752, Score: 0, Reward: 2.2000000000000015
# Episode: 10753, Score: 0, Reward: 3.9999999999999982
# Episode: 10754, Score: 0, Reward: 3.0000000000000018
# Episode: 10755, Score: 0, Reward: 3.0000000000000018
# Episode: 10756, Score: 0, Reward: 2.600000000000002
# Episode: 10757, Score: 0, Reward: 2.900000000000002
# Episode: 10758, Score: 0, Reward: 2.600000000000002
# Episode: 10759, Score: 0, Reward: 2.600000000000002
# Episode: 10760, Score: 0, Reward: 3.5
# Episode: 10761, Score: 0, Reward: 3.5
# Episode: 10762, Score: 0, Reward: 3.0000000000000018
# Episode: 10763, Score: 0, Reward: 3.4000000000000004
# Episode: 10764, Score: 0, Reward: 2.3000000000000016
# Episode: 10765, Score: 0, Reward: 2.3000000000000016
# Episode: 10766, Score: 0, Reward: 2.1000000000000014
# Episode: 10767, Score: 0, Reward: 3.4000000000000004
# Episode: 10768, Score: 0, Reward: 2.900000000000002
# Episode: 10769, Score: 0, Reward: 2.600000000000002
# Episode: 10770, Score: 0, Reward: 3.8999999999999986
# Episode: 10771, Score: 0, Reward: 2.2000000000000015
# Episode: 10772, Score: 0, Reward: 3.4000000000000004
# Episode: 10773, Score: 0, Reward: 3.200000000000001
# Episode: 10774, Score: 0, Reward: 2.5000000000000018
# Episode: 10775, Score: 0, Reward: 2.4000000000000017
# Episode: 10776, Score: 0, Reward: 3.9999999999999982
# Episode: 10777, Score: 0, Reward: 3.1000000000000014
# Episode: 10778, Score: 0, Reward: 3.799999999999999
# Episode: 10779, Score: 0, Reward: 2.900000000000002
# Episode: 10780, Score: 0, Reward: 3.200000000000001
# Episode: 10781, Score: 0, Reward: 3.0000000000000018
# Episode: 10782, Score: 0, Reward: 2.3000000000000016
# Episode: 10783, Score: 0, Reward: 2.800000000000002
# Episode: 10784, Score: 0, Reward: 2.3000000000000016
# Episode: 10785, Score: 0, Reward: 2.1000000000000014
# Episode: 10786, Score: 0, Reward: 4.4999999999999964
# Episode: 10787, Score: 0, Reward: 2.4000000000000017
# Episode: 10788, Score: 0, Reward: 2.3000000000000016
# Episode: 10789, Score: 0, Reward: 2.2000000000000015
# Episode: 10790, Score: 0, Reward: 2.4000000000000017
# Episode: 10791, Score: 0, Reward: 2.600000000000002
# Episode: 10792, Score: 0, Reward: 2.600000000000002
# Episode: 10793, Score: 0, Reward: 2.800000000000002
# Episode: 10794, Score: 0, Reward: 2.2000000000000015
# Episode: 10795, Score: 0, Reward: 3.8999999999999986
# Episode: 10796, Score: 0, Reward: 4.399999999999997
# Episode: 10797, Score: 0, Reward: 2.900000000000002
# Episode: 10798, Score: 0, Reward: 2.3000000000000016
# Episode: 10799, Score: 0, Reward: 2.1000000000000014
# Episode: 10800, Score: 0, Reward: 2.5000000000000018
# Episode: 10801, Score: 0, Reward: 6.29999999999999
# Episode: 10802, Score: 0, Reward: 3.4000000000000004
# Episode: 10803, Score: 0, Reward: 3.5999999999999996
# Episode: 10804, Score: 0, Reward: 5.5999999999999925
# Episode: 10805, Score: 0, Reward: 3.0000000000000018
# Episode: 10806, Score: 0, Reward: 3.5
# Episode: 10807, Score: 0, Reward: 2.3000000000000016
# Episode: 10808, Score: 0, Reward: 2.900000000000002
# Episode: 10809, Score: 0, Reward: 3.3000000000000007
# Episode: 10810, Score: 0, Reward: 2.5000000000000018
# Episode: 10811, Score: 0, Reward: 3.5999999999999996
# Episode: 10812, Score: 0, Reward: 2.800000000000002
# Episode: 10813, Score: 0, Reward: 2.3000000000000016
# Episode: 10814, Score: 0, Reward: 2.7000000000000024
# Episode: 10815, Score: 0, Reward: 3.799999999999999
# Episode: 10816, Score: 0, Reward: 3.8999999999999986
# Episode: 10817, Score: 0, Reward: 3.799999999999999
# Episode: 10818, Score: 0, Reward: 3.200000000000001
# Episode: 10819, Score: 0, Reward: 2.4000000000000017
# Episode: 10820, Score: 0, Reward: 2.1000000000000014
# Episode: 10821, Score: 0, Reward: 2.2000000000000015
# Episode: 10822, Score: 0, Reward: 2.600000000000002
# Episode: 10823, Score: 0, Reward: 2.7000000000000024
# Episode: 10824, Score: 0, Reward: 3.200000000000001
# Episode: 10825, Score: 0, Reward: 2.0000000000000013
# Episode: 10826, Score: 0, Reward: 2.4000000000000017
# Episode: 10827, Score: 0, Reward: 2.900000000000002
# Episode: 10828, Score: 0, Reward: 3.4000000000000004
# Episode: 10829, Score: 0, Reward: 2.4000000000000017
# Episode: 10830, Score: 0, Reward: 3.8999999999999986
# Episode: 10831, Score: 0, Reward: 5.699999999999992
# Episode: 10832, Score: 0, Reward: 3.5
# Episode: 10833, Score: 0, Reward: 2.800000000000002
# Episode: 10834, Score: 0, Reward: 4.299999999999997
# Episode: 10835, Score: 0, Reward: 2.800000000000002
# Episode: 10836, Score: 0, Reward: 3.4000000000000004
# Episode: 10837, Score: 0, Reward: 3.1000000000000014
# Episode: 10838, Score: 0, Reward: 2.3000000000000016
# Episode: 10839, Score: 0, Reward: 2.3000000000000016
# Episode: 10840, Score: 0, Reward: 2.900000000000002
# Episode: 10841, Score: 0, Reward: 2.2000000000000015
# Episode: 10842, Score: 0, Reward: 2.600000000000002
# Episode: 10843, Score: 0, Reward: 3.200000000000001
# Episode: 10844, Score: 0, Reward: 4.399999999999997
# Episode: 10845, Score: 0, Reward: 2.7000000000000024
# Episode: 10846, Score: 0, Reward: 2.4000000000000017
# Episode: 10847, Score: 0, Reward: 2.3000000000000016
# Episode: 10848, Score: 0, Reward: 5.199999999999994
# Episode: 10849, Score: 0, Reward: 4.1999999999999975
# Episode: 10850, Score: 0, Reward: 2.1000000000000014
# Episode: 10851, Score: 0, Reward: 2.800000000000002
# Episode: 10852, Score: 0, Reward: 3.8999999999999986
# Episode: 10853, Score: 0, Reward: 3.3000000000000007
# Episode: 10854, Score: 0, Reward: 3.799999999999999
# Episode: 10855, Score: 0, Reward: 2.2000000000000015
# Episode: 10856, Score: 0, Reward: 2.2000000000000015
# Episode: 10857, Score: 0, Reward: 4.1999999999999975
# Episode: 10858, Score: 0, Reward: 3.1000000000000014
# Episode: 10859, Score: 0, Reward: 2.2000000000000015
# Episode: 10860, Score: 0, Reward: 3.200000000000001
# Episode: 10861, Score: 0, Reward: 2.3000000000000016
# Episode: 10862, Score: 0, Reward: 3.4000000000000004
# Episode: 10863, Score: 0, Reward: 2.1000000000000014
# Episode: 10864, Score: 0, Reward: 2.2000000000000015
# Episode: 10865, Score: 0, Reward: 2.1000000000000014
# Episode: 10866, Score: 0, Reward: 2.3000000000000016
# Episode: 10867, Score: 0, Reward: 5.199999999999994
# Episode: 10868, Score: 0, Reward: 7.099999999999987
# Episode: 10869, Score: 0, Reward: 2.1000000000000014
# Episode: 10870, Score: 0, Reward: 3.3000000000000007
# Episode: 10871, Score: 0, Reward: 3.0000000000000018
# Episode: 10872, Score: 0, Reward: 2.7000000000000024
# Episode: 10873, Score: 0, Reward: 2.5000000000000018
# Episode: 10874, Score: 0, Reward: 3.5999999999999996
# Episode: 10875, Score: 0, Reward: 7.099999999999987
# Episode: 10876, Score: 0, Reward: 2.4000000000000017
# Episode: 10877, Score: 0, Reward: 2.1000000000000014
# Episode: 10878, Score: 0, Reward: 5.5999999999999925
# Episode: 10879, Score: 0, Reward: 3.1000000000000014
# Episode: 10880, Score: 0, Reward: 3.6999999999999993
# Episode: 10881, Score: 0, Reward: 2.7000000000000024
# Episode: 10882, Score: 0, Reward: 3.5
# Episode: 10883, Score: 0, Reward: 2.5000000000000018
# Episode: 10884, Score: 0, Reward: 3.1000000000000014
# Episode: 10885, Score: 0, Reward: 3.5999999999999996
# Episode: 10886, Score: 0, Reward: 2.5000000000000018
# Episode: 10887, Score: 0, Reward: 2.0000000000000013
# Episode: 10888, Score: 0, Reward: 2.600000000000002
# Episode: 10889, Score: 0, Reward: 3.1000000000000014
# Episode: 10890, Score: 0, Reward: 2.1000000000000014
# Episode: 10891, Score: 0, Reward: 2.1000000000000014
# Episode: 10892, Score: 0, Reward: 2.7000000000000024
# Episode: 10893, Score: 0, Reward: 2.600000000000002
# Episode: 10894, Score: 0, Reward: 3.5999999999999996
# Episode: 10895, Score: 0, Reward: 2.7000000000000024
# Episode: 10896, Score: 0, Reward: 2.3000000000000016
# Episode: 10897, Score: 0, Reward: 2.4000000000000017
# Episode: 10898, Score: 0, Reward: 3.0000000000000018
# Episode: 10899, Score: 0, Reward: 4.899999999999995
# Episode: 10900, Score: 0, Reward: 3.5999999999999996
# Episode: 10901, Score: 0, Reward: 4.999999999999995
# Episode: 10902, Score: 0, Reward: 3.9999999999999982
# Episode: 10903, Score: 0, Reward: 2.800000000000002
# Episode: 10904, Score: 0, Reward: 3.3000000000000007
# Episode: 10905, Score: 0, Reward: 2.5000000000000018
# Episode: 10906, Score: 0, Reward: 2.600000000000002
# Episode: 10907, Score: 0, Reward: 3.200000000000001
# Episode: 10908, Score: 0, Reward: 3.200000000000001
# Episode: 10909, Score: 0, Reward: 2.900000000000002
# Episode: 10910, Score: 0, Reward: 6.799999999999987
# Episode: 10911, Score: 0, Reward: 2.600000000000002
# Episode: 10912, Score: 0, Reward: 2.3000000000000016
# Episode: 10913, Score: 0, Reward: 2.800000000000002
# Episode: 10914, Score: 0, Reward: 4.599999999999996
# Episode: 10915, Score: 0, Reward: 6.29999999999999
# Episode: 10916, Score: 0, Reward: 3.799999999999999
# Episode: 10917, Score: 0, Reward: 2.600000000000002
# Episode: 10918, Score: 0, Reward: 3.4000000000000004
# Episode: 10919, Score: 0, Reward: 2.900000000000002
# Episode: 10920, Score: 0, Reward: 2.3000000000000016
# Episode: 10921, Score: 0, Reward: 2.7000000000000024
# Episode: 10922, Score: 0, Reward: 3.1000000000000014
# Episode: 10923, Score: 0, Reward: 2.900000000000002
# Episode: 10924, Score: 0, Reward: 2.2000000000000015
# Episode: 10925, Score: 0, Reward: 2.800000000000002
# ...
# Episode: 14716, Score: 0, Reward: 3.3000000000000007
# Episode: 14717, Score: 0, Reward: 7.099999999999987
# Episode: 14718, Score: 0, Reward: 7.099999999999987
# Episode: 14719, Score: 0, Reward: 6.599999999999989
# Episode: 14720, Score: 0, Reward: 6.099999999999991
# Episode: 14721, Score: 0, Reward: 3.8999999999999986
# Episode: 14722, Score: 0, Reward: 4.799999999999995
# Episode: 14723, Score: 0, Reward: 3.6999999999999993
# Episode: 14724, Score: 0, Reward: 2.900000000000002
# Episode: 14725, Score: 0, Reward: 6.799999999999987
# Episode: 14726, Score: 0, Reward: 6.19999999999999
# Episode: 14727, Score: 0, Reward: 3.3000000000000007
# Episode: 14728, Score: 0, Reward: 7.599999999999985
# Episode: 14729, Score: 0, Reward: 5.099999999999994
# Episode: 14730, Score: 0, Reward: 5.399999999999993
# Episode: 14731, Score: 0, Reward: 6.599999999999989
# Episode: 14732, Score: 0, Reward: 3.8999999999999986
# Episode: 14733, Score: 0, Reward: 7.099999999999987
# Episode: 14734, Score: 0, Reward: 6.49999999999999
# Episode: 14735, Score: 0, Reward: 7.2999999999999865
# Episode: 14736, Score: 1, Reward: 9.099999999999984
# Episode: 14737, Score: 0, Reward: 5.799999999999992
# Episode: 14738, Score: 0, Reward: 4.299999999999997
# Episode: 14739, Score: 0, Reward: 5.199999999999994
# Episode: 14740, Score: 0, Reward: 5.8999999999999915
# Episode: 14741, Score: 0, Reward: 6.39999999999999
# Episode: 14742, Score: 0, Reward: 3.9999999999999982
# Episode: 14743, Score: 0, Reward: 3.799999999999999
# Episode: 14744, Score: 0, Reward: 7.199999999999987
# Episode: 14745, Score: 0, Reward: 5.999999999999991
# Episode: 14746, Score: 0, Reward: 7.099999999999987
# Episode: 14747, Score: 0, Reward: 6.19999999999999
# Episode: 14748, Score: 0, Reward: 3.5999999999999996
# Episode: 14749, Score: 0, Reward: 6.799999999999987
# Episode: 14750, Score: 1, Reward: 9.099999999999984
# Episode: 14751, Score: 0, Reward: 7.099999999999987
# Episode: 14752, Score: 0, Reward: 7.099999999999987
# Episode: 14753, Score: 0, Reward: 6.39999999999999
# Episode: 14754, Score: 0, Reward: 7.099999999999987
# Episode: 14755, Score: 0, Reward: 5.199999999999994
# Episode: 14756, Score: 0, Reward: 5.199999999999994
# Episode: 14757, Score: 0, Reward: 7.099999999999987
# Episode: 14758, Score: 0, Reward: 7.099999999999987
# Episode: 14759, Score: 0, Reward: 7.099999999999987
# Episode: 14760, Score: 0, Reward: 5.999999999999991
# Episode: 14761, Score: 0, Reward: 6.39999999999999
# Episode: 14762, Score: 0, Reward: 4.599999999999996
# Episode: 14763, Score: 0, Reward: 7.099999999999987
# Episode: 14764, Score: 0, Reward: 5.299999999999994
# Episode: 14765, Score: 0, Reward: 5.499999999999993
# Episode: 14766, Score: 0, Reward: 7.099999999999987
# Episode: 14767, Score: 0, Reward: 5.499999999999993
# Episode: 14768, Score: 0, Reward: 6.29999999999999
# Episode: 14769, Score: 0, Reward: 7.099999999999987
# Episode: 14770, Score: 0, Reward: 3.1000000000000014
# Episode: 14771, Score: 0, Reward: 5.299999999999994
# Episode: 14772, Score: 0, Reward: 6.39999999999999
# Episode: 14773, Score: 0, Reward: 4.399999999999997
# Episode: 14774, Score: 0, Reward: 4.599999999999996
# Episode: 14775, Score: 0, Reward: 4.399999999999997
# Episode: 14776, Score: 0, Reward: 5.8999999999999915
# Episode: 14777, Score: 0, Reward: 4.1999999999999975
# Episode: 14778, Score: 0, Reward: 3.6999999999999993
# Episode: 14779, Score: 0, Reward: 6.899999999999987
# Episode: 14780, Score: 0, Reward: 4.1999999999999975
# Episode: 14781, Score: 0, Reward: 3.4000000000000004
# Episode: 14782, Score: 0, Reward: 5.199999999999994
# Episode: 14783, Score: 0, Reward: 3.799999999999999
# Episode: 14784, Score: 0, Reward: 3.799999999999999
# Episode: 14785, Score: 0, Reward: 7.199999999999987
# Episode: 14786, Score: 0, Reward: 3.9999999999999982
# Episode: 14787, Score: 0, Reward: 3.0000000000000018
# Episode: 14788, Score: 0, Reward: 5.399999999999993
# Episode: 14789, Score: 0, Reward: 5.999999999999991
# Episode: 14790, Score: 0, Reward: 7.099999999999987
# Episode: 14791, Score: 0, Reward: 3.8999999999999986
# Episode: 14792, Score: 0, Reward: 5.799999999999992
# Episode: 14793, Score: 0, Reward: 7.099999999999987
# Episode: 14794, Score: 0, Reward: 7.099999999999987
# Episode: 14795, Score: 0, Reward: 4.799999999999995
# Episode: 14796, Score: 0, Reward: 7.099999999999987
# Episode: 14797, Score: 0, Reward: 6.999999999999988
# Episode: 14798, Score: 0, Reward: 7.099999999999987
# Episode: 14799, Score: 0, Reward: 3.4000000000000004
# Episode: 14800, Score: 0, Reward: 4.099999999999998
# Episode: 14801, Score: 0, Reward: 4.299999999999997
# Episode: 14802, Score: 0, Reward: 4.699999999999996
# Episode: 14803, Score: 0, Reward: 7.099999999999987
# Episode: 14804, Score: 0, Reward: 6.49999999999999
# Episode: 14805, Score: 0, Reward: 6.599999999999989
# Episode: 14806, Score: 0, Reward: 4.299999999999997
# Episode: 14807, Score: 0, Reward: 4.699999999999996
# Episode: 14808, Score: 0, Reward: 7.199999999999987
# Episode: 14809, Score: 0, Reward: 3.5
# Episode: 14810, Score: 0, Reward: 5.099999999999994
# Episode: 14811, Score: 0, Reward: 6.899999999999987
# Episode: 14812, Score: 0, Reward: 6.099999999999991
# Episode: 14813, Score: 1, Reward: 9.199999999999983
# Episode: 14814, Score: 0, Reward: 3.200000000000001
# Episode: 14815, Score: 0, Reward: 7.099999999999987
# Episode: 14816, Score: 0, Reward: 3.200000000000001
# Episode: 14817, Score: 0, Reward: 6.099999999999991
# Episode: 14818, Score: 0, Reward: 2.7000000000000024
# Episode: 14819, Score: 0, Reward: 6.599999999999989
# Episode: 14820, Score: 0, Reward: 7.099999999999987
# Episode: 14821, Score: 0, Reward: 2.600000000000002
# Episode: 14822, Score: 0, Reward: 5.799999999999992
# Episode: 14823, Score: 0, Reward: 3.6999999999999993
# Episode: 14824, Score: 0, Reward: 7.699999999999985
# Episode: 14825, Score: 0, Reward: 3.4000000000000004
# Episode: 14826, Score: 0, Reward: 4.399999999999997
# Episode: 14827, Score: 0, Reward: 3.9999999999999982
# Episode: 14828, Score: 0, Reward: 6.19999999999999
# Episode: 14829, Score: 0, Reward: 4.999999999999995
# Episode: 14830, Score: 0, Reward: 5.099999999999994
# Episode: 14831, Score: 0, Reward: 4.1999999999999975
# Episode: 14832, Score: 0, Reward: 5.499999999999993
# Episode: 14833, Score: 0, Reward: 5.8999999999999915
# Episode: 14834, Score: 1, Reward: 9.199999999999983
# Episode: 14835, Score: 0, Reward: 7.199999999999987
# Episode: 14836, Score: 0, Reward: 7.099999999999987
# Episode: 14837, Score: 0, Reward: 5.099999999999994
# Episode: 14838, Score: 0, Reward: 7.099999999999987
# Episode: 14839, Score: 0, Reward: 7.099999999999987
# Episode: 14840, Score: 0, Reward: 6.699999999999989
# Episode: 14841, Score: 0, Reward: 3.6999999999999993
# Episode: 14842, Score: 0, Reward: 2.800000000000002
# Episode: 14843, Score: 0, Reward: 6.29999999999999
# Episode: 14844, Score: 0, Reward: 7.099999999999987
# Episode: 14845, Score: 0, Reward: 2.900000000000002
# Episode: 14846, Score: 0, Reward: 6.699999999999989
# Episode: 14847, Score: 0, Reward: 4.899999999999995
# Episode: 14848, Score: 0, Reward: 3.5
# Episode: 14849, Score: 0, Reward: 7.099999999999987
# Episode: 14850, Score: 0, Reward: 7.099999999999987
# Episode: 14851, Score: 0, Reward: 7.099999999999987
# Episode: 14852, Score: 0, Reward: 3.200000000000001
# Episode: 14853, Score: 0, Reward: 7.099999999999987
# Episode: 14854, Score: 0, Reward: 7.099999999999987
# Episode: 14855, Score: 0, Reward: 5.699999999999992
# Episode: 14856, Score: 0, Reward: 7.099999999999987
# Episode: 14857, Score: 0, Reward: 6.899999999999987
# Episode: 14858, Score: 0, Reward: 3.4000000000000004
# Episode: 14859, Score: 1, Reward: 9.399999999999983
# Episode: 14860, Score: 0, Reward: 7.099999999999987
# Episode: 14861, Score: 0, Reward: 7.099999999999987
# Episode: 14862, Score: 0, Reward: 3.8999999999999986
# Episode: 14863, Score: 1, Reward: 8.899999999999984
# Episode: 14864, Score: 0, Reward: 4.599999999999996
# Episode: 14865, Score: 0, Reward: 3.5999999999999996
# Episode: 14866, Score: 0, Reward: 5.799999999999992
# Episode: 14867, Score: 0, Reward: 5.199999999999994
# Episode: 14868, Score: 0, Reward: 3.4000000000000004
# Episode: 14869, Score: 0, Reward: 4.899999999999995
# Episode: 14870, Score: 0, Reward: 2.900000000000002
# Episode: 14871, Score: 0, Reward: 5.8999999999999915
# Episode: 14872, Score: 0, Reward: 4.699999999999996
# Episode: 14873, Score: 0, Reward: 7.099999999999987
# Episode: 14874, Score: 0, Reward: 5.8999999999999915
# Episode: 14875, Score: 0, Reward: 7.099999999999987
# Episode: 14876, Score: 0, Reward: 7.099999999999987
# Episode: 14877, Score: 0, Reward: 7.099999999999987
# Episode: 14878, Score: 0, Reward: 7.099999999999987
# Episode: 14879, Score: 0, Reward: 7.099999999999987
# Episode: 14880, Score: 0, Reward: 7.099999999999987
# Episode: 14881, Score: 0, Reward: 6.799999999999987
# Episode: 14882, Score: 0, Reward: 7.699999999999985
# Episode: 14883, Score: 1, Reward: 8.899999999999984
# Episode: 14884, Score: 0, Reward: 4.099999999999998
# Episode: 14885, Score: 0, Reward: 6.29999999999999
# Episode: 14886, Score: 0, Reward: 7.499999999999987
# Episode: 14887, Score: 0, Reward: 7.099999999999987
# Episode: 14888, Score: 0, Reward: 5.999999999999991
# Episode: 14889, Score: 0, Reward: 7.099999999999987
# Episode: 14890, Score: 0, Reward: 7.099999999999987
# Episode: 14891, Score: 0, Reward: 5.099999999999994
# Episode: 14892, Score: 0, Reward: 5.699999999999992
# Episode: 14893, Score: 1, Reward: 8.999999999999984
# Episode: 14894, Score: 0, Reward: 3.4000000000000004
# Episode: 14895, Score: 0, Reward: 5.499999999999993
# Episode: 14896, Score: 0, Reward: 7.099999999999987
# Episode: 14897, Score: 0, Reward: 4.299999999999997
# Episode: 14898, Score: 0, Reward: 6.699999999999989
# Episode: 14899, Score: 0, Reward: 3.8999999999999986
# Episode: 14900, Score: 0, Reward: 6.19999999999999
# Episode: 14901, Score: 0, Reward: 7.099999999999987
# Episode: 14902, Score: 0, Reward: 7.499999999999987
# Episode: 14903, Score: 0, Reward: 5.5999999999999925
# Episode: 14904, Score: 0, Reward: 7.099999999999987
# Episode: 14905, Score: 0, Reward: 6.29999999999999
# Episode: 14906, Score: 0, Reward: 7.099999999999987
# Episode: 14907, Score: 0, Reward: 6.19999999999999
# Episode: 14908, Score: 0, Reward: 2.900000000000002
# Episode: 14909, Score: 0, Reward: 7.099999999999987
# Episode: 14910, Score: 0, Reward: 7.099999999999987
# Episode: 14911, Score: 0, Reward: 4.599999999999996
# Episode: 14912, Score: 0, Reward: 5.399999999999993
# Episode: 14913, Score: 0, Reward: 6.899999999999987
# Episode: 14914, Score: 0, Reward: 7.099999999999987
# Episode: 14915, Score: 0, Reward: 6.599999999999989
# Episode: 14916, Score: 0, Reward: 5.999999999999991
# Episode: 14917, Score: 0, Reward: 7.099999999999987
# Episode: 14918, Score: 0, Reward: 4.599999999999996
# Episode: 14919, Score: 0, Reward: 3.3000000000000007
# Episode: 14920, Score: 0, Reward: 5.8999999999999915
# Episode: 14921, Score: 0, Reward: 6.29999999999999
# Episode: 14922, Score: 0, Reward: 3.5
# Episode: 14923, Score: 0, Reward: 7.099999999999987
# Episode: 14924, Score: 0, Reward: 7.099999999999987
# Episode: 14925, Score: 0, Reward: 5.399999999999993
# Episode: 14926, Score: 0, Reward: 4.299999999999997
# Episode: 14927, Score: 0, Reward: 4.599999999999996
# Episode: 14928, Score: 0, Reward: 2.3000000000000016
# Episode: 14929, Score: 0, Reward: 7.099999999999987
# Episode: 14930, Score: 0, Reward: 7.099999999999987
# Episode: 14931, Score: 0, Reward: 4.899999999999995
# Episode: 14932, Score: 1, Reward: 8.999999999999984
# Episode: 14933, Score: 0, Reward: 4.1999999999999975
# Episode: 14934, Score: 0, Reward: 4.1999999999999975
# Episode: 14935, Score: 0, Reward: 4.799999999999995
# Episode: 14936, Score: 0, Reward: 6.599999999999989
# Episode: 14937, Score: 0, Reward: 3.0000000000000018
# Episode: 14938, Score: 0, Reward: 7.099999999999987
# Episode: 14939, Score: 0, Reward: 5.8999999999999915
# Episode: 14940, Score: 0, Reward: 5.199999999999994
# Episode: 14941, Score: 0, Reward: 7.2999999999999865
# Episode: 14942, Score: 0, Reward: 4.1999999999999975
# Episode: 14943, Score: 0, Reward: 4.399999999999997
# Episode: 14944, Score: 0, Reward: 7.2999999999999865
# Episode: 14945, Score: 0, Reward: 7.099999999999987
# Episode: 14946, Score: 0, Reward: 7.099999999999987
# Episode: 14947, Score: 0, Reward: 7.099999999999987
# Episode: 14948, Score: 0, Reward: 3.6999999999999993
# Episode: 14949, Score: 0, Reward: 3.5
# Episode: 14950, Score: 0, Reward: 5.5999999999999925
# Episode: 14951, Score: 0, Reward: 6.49999999999999
# Episode: 14952, Score: 0, Reward: 7.099999999999987
# Episode: 14953, Score: 0, Reward: 6.099999999999991
# Episode: 14954, Score: 0, Reward: 7.099999999999987
# Episode: 14955, Score: 0, Reward: 3.5999999999999996
# Episode: 14956, Score: 0, Reward: 5.699999999999992
# Episode: 14957, Score: 0, Reward: 5.999999999999991
# Episode: 14958, Score: 0, Reward: 4.699999999999996
# Episode: 14959, Score: 0, Reward: 2.800000000000002
# Episode: 14960, Score: 0, Reward: 7.099999999999987
# Episode: 14961, Score: 0, Reward: 4.699999999999996
# Episode: 14962, Score: 0, Reward: 4.299999999999997
# Episode: 14963, Score: 0, Reward: 4.799999999999995
# Episode: 14964, Score: 0, Reward: 7.099999999999987
# Episode: 14965, Score: 0, Reward: 6.099999999999991
# Episode: 14966, Score: 0, Reward: 7.599999999999985
# Episode: 14967, Score: 0, Reward: 7.099999999999987
# Episode: 14968, Score: 0, Reward: 7.099999999999987
# Episode: 14969, Score: 0, Reward: 5.699999999999992
# Episode: 14970, Score: 0, Reward: 3.3000000000000007
# Episode: 14971, Score: 0, Reward: 6.999999999999988
# Episode: 14972, Score: 0, Reward: 2.5000000000000018
# Episode: 14973, Score: 0, Reward: 4.999999999999995
# Episode: 14974, Score: 0, Reward: 6.799999999999987
# Episode: 14975, Score: 0, Reward: 5.199999999999994
# Episode: 14976, Score: 0, Reward: 3.1000000000000014
# Episode: 14977, Score: 0, Reward: 4.999999999999995
# Episode: 14978, Score: 0, Reward: 3.6999999999999993
# Episode: 14979, Score: 0, Reward: 4.699999999999996
# Episode: 14980, Score: 0, Reward: 6.29999999999999
# Episode: 14981, Score: 0, Reward: 5.299999999999994
# Episode: 14982, Score: 0, Reward: 6.599999999999989
# Episode: 14983, Score: 0, Reward: 4.699999999999996
# Episode: 14984, Score: 0, Reward: 4.1999999999999975
# Episode: 14985, Score: 0, Reward: 5.199999999999994
# Episode: 14986, Score: 0, Reward: 6.099999999999991
# Episode: 14987, Score: 0, Reward: 7.099999999999987
# Episode: 14988, Score: 0, Reward: 3.200000000000001
# Episode: 14989, Score: 0, Reward: 3.3000000000000007
# Episode: 14990, Score: 0, Reward: 7.099999999999987
# Episode: 14991, Score: 0, Reward: 4.4999999999999964
# Episode: 14992, Score: 0, Reward: 7.099999999999987
# Episode: 14993, Score: 0, Reward: 3.9999999999999982
# Episode: 14994, Score: 0, Reward: 6.49999999999999
# Episode: 14995, Score: 0, Reward: 4.699999999999996
# Episode: 14996, Score: 0, Reward: 2.7000000000000024
# Episode: 14997, Score: 0, Reward: 4.899999999999995
# Episode: 14998, Score: 0, Reward: 3.6999999999999993
# Episode: 14999, Score: 0, Reward: 2.800000000000002
# Episode: 15000, Score: 0, Reward: 4.699999999999996
# Episode: 15001, Score: 1, Reward: 8.999999999999984
# Episode: 15002, Score: 0, Reward: 3.3000000000000007
# Episode: 15003, Score: 0, Reward: 7.099999999999987
# Episode: 15004, Score: 0, Reward: 7.199999999999987
# Episode: 15005, Score: 0, Reward: 4.399999999999997
# Episode: 15006, Score: 0, Reward: 5.299999999999994
# Episode: 15007, Score: 0, Reward: 5.8999999999999915
# Episode: 15008, Score: 0, Reward: 6.999999999999988
# Episode: 15009, Score: 0, Reward: 7.099999999999987
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-30b7e425d582> in <module>()
#      49         # epsilon-greedy search (select action)
#      50         action = select_action(state)
# ---> 51         screen, reward, done = env.step(action.item())
#      52         rewards += reward
#      53
#
# <ipython-input-5-e3ca6aff065a> in step(self, action)
#     194         pygame.display.update()
#     195         screen = array3d(pygame.display.get_surface())
# --> 196         self.clock.tick(self.fps)
#     197
#     198         return screen, reward, terminal
#
# KeyboardInterrupt:

# %%
steps_done
# Out:
# 2258545

# %%
import pickle

with open('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/avg.txt', 'wb') as fp:
    pickle.dump(average_per_episode, fp)

with open('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/score.txt', 'wb') as fp:
    pickle.dump(score_per_episode, fp)

with open('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/sequence.txt', 'wb') as fp:
    pickle.dump(seq_length, fp)

# %%
with open ('/content/drive/MyDrive/Colab Notebooks/FlappyBird/avg.txt', 'rb') as fp:
    average_per_episode = pickle.load(fp)

with open ('/content/drive/MyDrive/Colab Notebooks/FlappyBird/score.txt', 'rb') as fp:
    score_per_episode = pickle.load(fp)

with open ('/content/drive/MyDrive/Colab Notebooks/FlappyBird/sequence.txt', 'rb') as fp:
    seq_length = pickle.load(fp)

# %%
resize = T.Compose([T.ToPILImage(),
                    T.Grayscale(),
                    T.CenterCrop((288, 288)),
                    T.Resize(84),
                    T.ToTensor()])

# hyperparameters
BATCH_SIZE = 64
GAMMA = 0.99 # discount factor
EPS_START = 1
EPS_END = 0.05
EPS_DECAY = 400000
TARGET_UPDATE = 10

n_actions = 2

# create networks
policy_net = DQN(n_actions).to(device)
policy_net.load_state_dict(torch.load('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/state_dict_model_27500.pt'))

target_net = DQN(n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = torch.optim.Adam(policy_net.parameters(), lr=1e-6)
# optimizer = torch.optim.RMSprop(policy_net.parameters(), lr=1e-6, weight_decay=0.9, momentum=0.95)
criterion = nn.MSELoss()

# memory = ReplayMemory(10000)


'''
with open ('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/avg.txt', 'rb') as fp:
    average_per_episode = pickle.load(fp)

with open ('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/score.txt', 'rb') as fp:
    score_per_episode = pickle.load(fp)

with open ('/content/drive/MyDrive/Colab_Notebooks/FlappyBird/sequence.txt', 'rb') as fp:
    seq_length = pickle.load(fp)
'''

num_episodes = int(1e5)
for i_episode in range(30001, num_episodes):
    rewards = 0

    # Initialize the environment and state
    env.reset()

    init_screen = env.get_screen()

    init_screen = resize(init_screen)
    # (N, C, H, W): (1, 4, 84, 84)
    state = torch.cat(tuple(init_screen for _ in range(4))).unsqueeze(0).to(device)
    
    # state = resize(init_screen).unsqueeze(0).to(device)

    for t in count():
        # epsilon-greedy search (select action)
        action = select_action(state)
        screen, reward, done = env.step(action.item())
        rewards += reward

        screen = resize(screen).to(device)
        # next_state = resize(screen).unsqueeze(0).to(device)
        reward = torch.tensor([reward], device=device)

        next_state = torch.cat((state[0, 1:], screen)).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        if len(memory) >= 2 * BATCH_SIZE:
            for j in range(2):
                transitions = memory.sample(BATCH_SIZE)

                # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
                # detailed explanation). This converts batch-array of Transitions
                # to Transition of batch-arrays.
                batch = Transition(*zip(*transitions))

                # Compute a mask of non-final states and concatenate the batch elements
                # (a final state would've been the one after which simulation ended)
                non_final_mask = torch.tensor(tuple(map(lambda s: s != -1,
                                                        batch.reward)), device=device, dtype=torch.bool)
                
                non_final_next_states = torch.cat([s for s, r in zip(batch.next_state, batch.reward)
                                                if r != -1])

                state_batch = torch.cat(batch.state)
                action_batch = torch.cat(batch.action)
                reward_batch = torch.cat(batch.reward)

                # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
                # columns of actions taken. These are the actions which would've been taken
                # for each batch state according to policy_net
                state_action_values = policy_net(state_batch).gather(1, action_batch)

                # Compute V(s_{t+1}) for all next states.
                # Expected values of actions for non_final_next_states are computed based
                # on the "older" target_net; selecting their best reward with max(1)[0].
                # This is merged based on the mask, such that we'll have either the expected
                # state value or 0 in case the state was final.
                next_state_values = torch.zeros(BATCH_SIZE, device=device)
                next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()

                # Compute the expected Q values
                expected_state_action_values = (next_state_values * GAMMA) + reward_batch

                loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

                # Optimize the model
                optimizer.zero_grad()
                loss.backward()

                '''
                for param in policy_net.parameters():
                    param.grad.data.clamp_(-1, 1)
                '''

                optimizer.step()

        if done or t > 5000:
            average_per_episode.append(rewards/t)
            score_per_episode.append(env.score)
            seq_length.append(t)
            break
    
    print('Episode: {}, Score: {}, Reward: {}, Steps done: {}'.format(i_episode, env.score, rewards, steps_done))

    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

    if i_episode % 500 == 0:
        
        PATH = '/content/drive/MyDrive/Colab_Notebooks/FlappyBird/state_dict_model_' + str(i_episode) + '.pt'
        torch.save(policy_net.state_dict(), PATH, _use_new_zipfile_serialization=False)
        

print('Complete')
# Out:
# Episode: 27501, Score: 2, Reward: 17.099999999999994, Steps done: 1842713
# Episode: 27502, Score: 2, Reward: 16.999999999999993, Steps done: 1842876
# Episode: 27503, Score: 0, Reward: 6.799999999999988, Steps done: 1842955
# Episode: 27504, Score: 0, Reward: 7.499999999999986, Steps done: 1843041
# Episode: 27505, Score: 1, Reward: 11.899999999999974, Steps done: 1843162
# Episode: 27506, Score: 2, Reward: 17.099999999999994, Steps done: 1843326
# Episode: 27507, Score: 2, Reward: 16.69999999999999, Steps done: 1843486
# Episode: 27508, Score: 2, Reward: 17.5, Steps done: 1843654
# Episode: 27509, Score: 0, Reward: 5.099999999999994, Steps done: 1843716
# Episode: 27510, Score: 2, Reward: 17.299999999999997, Steps done: 1843882
# Episode: 27511, Score: 1, Reward: 11.999999999999973, Steps done: 1844004
# Episode: 27512, Score: 2, Reward: 17.4, Steps done: 1844171
# Episode: 27513, Score: 0, Reward: 6.799999999999988, Steps done: 1844250
# Episode: 27514, Score: 0, Reward: 6.899999999999988, Steps done: 1844330
# Episode: 27515, Score: 0, Reward: 4.699999999999996, Steps done: 1844388
# Episode: 27516, Score: 0, Reward: 4.699999999999996, Steps done: 1844446
# Episode: 27517, Score: 1, Reward: 11.999999999999973, Steps done: 1844568
# Episode: 27518, Score: 3, Reward: 23.40000000000007, Steps done: 1844786
# Episode: 27519, Score: 11, Reward: 63.50000000000048, Steps done: 1845333
# Episode: 27520, Score: 0, Reward: 6.799999999999988, Steps done: 1845412
# Episode: 27521, Score: 2, Reward: 17.4, Steps done: 1845579
# Episode: 27522, Score: 5, Reward: 32.60000000000017, Steps done: 1845871
# Episode: 27523, Score: 1, Reward: 12.199999999999973, Steps done: 1845995
# Episode: 27524, Score: 0, Reward: 7.099999999999987, Steps done: 1846077
# Episode: 27525, Score: 0, Reward: 7.699999999999985, Steps done: 1846165
# Episode: 27526, Score: 1, Reward: 12.99999999999997, Steps done: 1846297
# Episode: 27527, Score: 0, Reward: 7.199999999999987, Steps done: 1846380
# Episode: 27528, Score: 3, Reward: 19.400000000000013, Steps done: 1846558
# Episode: 27529, Score: 2, Reward: 17.099999999999994, Steps done: 1846722
# Episode: 27530, Score: 0, Reward: 5.399999999999993, Steps done: 1846787
# Episode: 27531, Score: 2, Reward: 17.099999999999994, Steps done: 1846951
# Episode: 27532, Score: 0, Reward: 6.39999999999999, Steps done: 1847026
# Episode: 27533, Score: 3, Reward: 22.300000000000054, Steps done: 1847233
# Episode: 27534, Score: 9, Reward: 53.20000000000041, Steps done: 1847695
# Episode: 27535, Score: 0, Reward: 6.799999999999988, Steps done: 1847774
# Episode: 27536, Score: 2, Reward: 17.099999999999994, Steps done: 1847938
# Episode: 27537, Score: 0, Reward: 7.399999999999986, Steps done: 1848023
# Episode: 27538, Score: 4, Reward: 24.900000000000077, Steps done: 1848247
# Episode: 27539, Score: 0, Reward: 5.8999999999999915, Steps done: 1848317
# Episode: 27540, Score: 0, Reward: 4.799999999999995, Steps done: 1848376
# Episode: 27541, Score: 0, Reward: 6.799999999999988, Steps done: 1848455
# Episode: 27542, Score: 0, Reward: 6.899999999999988, Steps done: 1848535
# Episode: 27543, Score: 1, Reward: 12.099999999999973, Steps done: 1848658
# Episode: 27544, Score: 2, Reward: 17.099999999999994, Steps done: 1848822
# Episode: 27545, Score: 8, Reward: 48.00000000000035, Steps done: 1849241
# Episode: 27546, Score: 0, Reward: 6.799999999999988, Steps done: 1849320
# Episode: 27547, Score: 1, Reward: 11.999999999999973, Steps done: 1849442
# Episode: 27548, Score: 1, Reward: 8.999999999999984, Steps done: 1849534
# Episode: 27549, Score: 3, Reward: 22.300000000000054, Steps done: 1849741
# Episode: 27550, Score: 1, Reward: 12.199999999999973, Steps done: 1849865
# Episode: 27551, Score: 2, Reward: 14.499999999999968, Steps done: 1850003
# Episode: 27552, Score: 3, Reward: 21.20000000000004, Steps done: 1850199
# Episode: 27553, Score: 3, Reward: 22.300000000000054, Steps done: 1850406
# Episode: 27554, Score: 0, Reward: 4.4999999999999964, Steps done: 1850462
# Episode: 27555, Score: 4, Reward: 27.800000000000118, Steps done: 1850715
# Episode: 27556, Score: 1, Reward: 11.999999999999973, Steps done: 1850837
# Episode: 27557, Score: 1, Reward: 11.899999999999974, Steps done: 1850958
# Episode: 27558, Score: 1, Reward: 11.899999999999974, Steps done: 1851079
# Episode: 27559, Score: 7, Reward: 42.90000000000029, Steps done: 1851456
# Episode: 27560, Score: 0, Reward: 4.1999999999999975, Steps done: 1851509
# Episode: 27561, Score: 1, Reward: 11.899999999999974, Steps done: 1851630
# Episode: 27562, Score: 2, Reward: 17.099999999999994, Steps done: 1851794
# Episode: 27563, Score: 0, Reward: 6.799999999999988, Steps done: 1851873
# Episode: 27564, Score: 3, Reward: 22.300000000000054, Steps done: 1852080
# Episode: 27565, Score: 1, Reward: 11.999999999999973, Steps done: 1852202
# Episode: 27566, Score: 2, Reward: 17.4, Steps done: 1852369
# Episode: 27567, Score: 0, Reward: 6.799999999999988, Steps done: 1852448
# Episode: 27568, Score: 0, Reward: 6.899999999999988, Steps done: 1852528
# Episode: 27569, Score: 0, Reward: 5.199999999999994, Steps done: 1852591
# Episode: 27570, Score: 4, Reward: 27.400000000000112, Steps done: 1852840
# Episode: 27571, Score: 3, Reward: 22.300000000000054, Steps done: 1853047
# Episode: 27572, Score: 0, Reward: 6.799999999999988, Steps done: 1853126
# Episode: 27573, Score: 2, Reward: 14.199999999999969, Steps done: 1853261
# Episode: 27574, Score: 1, Reward: 11.999999999999973, Steps done: 1853383
# Episode: 27575, Score: 1, Reward: 11.999999999999973, Steps done: 1853505
# Episode: 27576, Score: 1, Reward: 11.899999999999974, Steps done: 1853626
# Episode: 27577, Score: 1, Reward: 11.899999999999974, Steps done: 1853747
# Episode: 27578, Score: 2, Reward: 14.399999999999968, Steps done: 1853884
# Episode: 27579, Score: 0, Reward: 6.099999999999991, Steps done: 1853956
# Episode: 27580, Score: 3, Reward: 22.300000000000054, Steps done: 1854163
# Episode: 27581, Score: 2, Reward: 17.099999999999994, Steps done: 1854327
# Episode: 27582, Score: 1, Reward: 11.899999999999974, Steps done: 1854448
# Episode: 27583, Score: 0, Reward: 3.9999999999999982, Steps done: 1854499
# Episode: 27584, Score: 0, Reward: 4.1999999999999975, Steps done: 1854552
# Episode: 27585, Score: 0, Reward: 5.099999999999994, Steps done: 1854614
# Episode: 27586, Score: 3, Reward: 22.400000000000055, Steps done: 1854822
# Episode: 27587, Score: 1, Reward: 11.899999999999974, Steps done: 1854943
# Episode: 27588, Score: 0, Reward: 7.799999999999985, Steps done: 1855032
# Episode: 27589, Score: 0, Reward: 6.899999999999988, Steps done: 1855112
# Episode: 27590, Score: 4, Reward: 27.400000000000112, Steps done: 1855361
# Episode: 27591, Score: 0, Reward: 4.599999999999996, Steps done: 1855418
# Episode: 27592, Score: 5, Reward: 33.30000000000018, Steps done: 1855717
# Episode: 27593, Score: 1, Reward: 11.899999999999974, Steps done: 1855838
# Episode: 27594, Score: 2, Reward: 17.099999999999994, Steps done: 1856002
# Episode: 27595, Score: 1, Reward: 11.999999999999973, Steps done: 1856124
# Episode: 27596, Score: 0, Reward: 7.599999999999985, Steps done: 1856211
# Episode: 27597, Score: 1, Reward: 7.999999999999984, Steps done: 1856302
# Episode: 27598, Score: 1, Reward: 11.999999999999973, Steps done: 1856424
# Episode: 27599, Score: 1, Reward: 11.999999999999973, Steps done: 1856546
# Episode: 27600, Score: 1, Reward: 12.99999999999997, Steps done: 1856678
# Episode: 27601, Score: 0, Reward: 6.899999999999988, Steps done: 1856758
# Episode: 27602, Score: 0, Reward: 6.899999999999988, Steps done: 1856838
# Episode: 27603, Score: 0, Reward: 4.4999999999999964, Steps done: 1856894
# Episode: 27604, Score: 0, Reward: 6.799999999999988, Steps done: 1856973
# Episode: 27605, Score: 1, Reward: 11.999999999999973, Steps done: 1857095
# Episode: 27606, Score: 0, Reward: 7.099999999999987, Steps done: 1857177
# Episode: 27607, Score: 1, Reward: 11.999999999999973, Steps done: 1857299
# Episode: 27608, Score: 2, Reward: 13.199999999999969, Steps done: 1857433
# Episode: 27609, Score: 0, Reward: 7.399999999999986, Steps done: 1857518
# Episode: 27610, Score: 4, Reward: 27.700000000000117, Steps done: 1857770
# Episode: 27611, Score: 2, Reward: 17.199999999999996, Steps done: 1857935
# Episode: 27612, Score: 1, Reward: 12.199999999999973, Steps done: 1858059
# Episode: 27613, Score: 3, Reward: 23.40000000000007, Steps done: 1858277
# Episode: 27614, Score: 7, Reward: 42.90000000000029, Steps done: 1858654
# Episode: 27615, Score: 0, Reward: 6.599999999999989, Steps done: 1858731
# Episode: 27616, Score: 0, Reward: 6.999999999999988, Steps done: 1858812
# Episode: 27617, Score: 1, Reward: 11.899999999999974, Steps done: 1858933
# Episode: 27618, Score: 4, Reward: 26.700000000000102, Steps done: 1859175
# Episode: 27619, Score: 0, Reward: 4.099999999999998, Steps done: 1859227
# Episode: 27620, Score: 1, Reward: 11.999999999999973, Steps done: 1859349
# Episode: 27621, Score: 1, Reward: 11.999999999999973, Steps done: 1859471
# Episode: 27622, Score: 0, Reward: 7.599999999999985, Steps done: 1859558
# Episode: 27623, Score: 0, Reward: 6.799999999999988, Steps done: 1859637
# Episode: 27624, Score: 1, Reward: 12.399999999999972, Steps done: 1859763
# Episode: 27625, Score: 3, Reward: 22.300000000000054, Steps done: 1859970
# Episode: 27626, Score: 2, Reward: 17.099999999999994, Steps done: 1860134
# Episode: 27627, Score: 2, Reward: 17.099999999999994, Steps done: 1860298
# Episode: 27628, Score: 3, Reward: 22.300000000000054, Steps done: 1860505
# Episode: 27629, Score: 1, Reward: 9.299999999999983, Steps done: 1860600
# Episode: 27630, Score: 1, Reward: 11.899999999999974, Steps done: 1860721
# Episode: 27631, Score: 1, Reward: 11.899999999999974, Steps done: 1860842
# Episode: 27632, Score: 6, Reward: 37.70000000000023, Steps done: 1861176
# Episode: 27633, Score: 2, Reward: 17.299999999999997, Steps done: 1861342
# Episode: 27634, Score: 1, Reward: 11.999999999999973, Steps done: 1861464
# Episode: 27635, Score: 3, Reward: 19.90000000000002, Steps done: 1861647
# Episode: 27636, Score: 1, Reward: 11.899999999999974, Steps done: 1861768
# Episode: 27637, Score: 3, Reward: 22.300000000000054, Steps done: 1861975
# Episode: 27638, Score: 2, Reward: 17.4, Steps done: 1862142
# Episode: 27639, Score: 1, Reward: 11.899999999999974, Steps done: 1862263
# Episode: 27640, Score: 5, Reward: 30.30000000000014, Steps done: 1862532
# Episode: 27641, Score: 0, Reward: 6.799999999999988, Steps done: 1862611
# Episode: 27642, Score: 1, Reward: 11.999999999999973, Steps done: 1862733
# Episode: 27643, Score: 1, Reward: 11.899999999999974, Steps done: 1862854
# Episode: 27644, Score: 1, Reward: 11.899999999999974, Steps done: 1862975
# Episode: 27645, Score: 0, Reward: 6.799999999999988, Steps done: 1863054
# Episode: 27646, Score: 0, Reward: 6.799999999999988, Steps done: 1863133
# Episode: 27647, Score: 2, Reward: 17.199999999999996, Steps done: 1863298
# Episode: 27648, Score: 0, Reward: 5.5999999999999925, Steps done: 1863365
# Episode: 27649, Score: 1, Reward: 11.999999999999973, Steps done: 1863487
# Episode: 27650, Score: 0, Reward: 5.399999999999993, Steps done: 1863552
# Episode: 27651, Score: 0, Reward: 6.799999999999988, Steps done: 1863631
# Episode: 27652, Score: 0, Reward: 4.799999999999995, Steps done: 1863690
# Episode: 27653, Score: 4, Reward: 27.400000000000112, Steps done: 1863939
# Episode: 27654, Score: 0, Reward: 6.799999999999988, Steps done: 1864018
# Episode: 27655, Score: 0, Reward: 6.799999999999988, Steps done: 1864097
# Episode: 27656, Score: 1, Reward: 9.299999999999983, Steps done: 1864192
# Episode: 27657, Score: 0, Reward: 7.599999999999985, Steps done: 1864279
# Episode: 27658, Score: 0, Reward: 5.8999999999999915, Steps done: 1864349
# Episode: 27659, Score: 1, Reward: 11.999999999999973, Steps done: 1864471
# Episode: 27660, Score: 0, Reward: 6.799999999999988, Steps done: 1864550
# Episode: 27661, Score: 0, Reward: 7.899999999999984, Steps done: 1864640
# Episode: 27662, Score: 0, Reward: 6.799999999999988, Steps done: 1864719
# Episode: 27663, Score: 5, Reward: 33.40000000000018, Steps done: 1865019
# Episode: 27664, Score: 2, Reward: 17.199999999999996, Steps done: 1865184
# Episode: 27665, Score: 3, Reward: 22.300000000000054, Steps done: 1865391
# Episode: 27666, Score: 0, Reward: 7.399999999999986, Steps done: 1865476
# Episode: 27667, Score: 4, Reward: 27.90000000000012, Steps done: 1865730
# Episode: 27668, Score: 5, Reward: 29.70000000000013, Steps done: 1865993
# Episode: 27669, Score: 5, Reward: 32.60000000000017, Steps done: 1866285
# Episode: 27670, Score: 1, Reward: 9.199999999999983, Steps done: 1866379
# Episode: 27671, Score: 0, Reward: 7.599999999999985, Steps done: 1866466
# Episode: 27672, Score: 0, Reward: 6.799999999999988, Steps done: 1866545
# Episode: 27673, Score: 2, Reward: 17.199999999999996, Steps done: 1866710
# Episode: 27674, Score: 0, Reward: 6.799999999999988, Steps done: 1866789
# Episode: 27675, Score: 0, Reward: 6.899999999999988, Steps done: 1866869
# Episode: 27676, Score: 8, Reward: 48.90000000000036, Steps done: 1867297
# Episode: 27677, Score: 3, Reward: 22.200000000000053, Steps done: 1867503
# Episode: 27678, Score: 2, Reward: 17.099999999999994, Steps done: 1867667
# Episode: 27679, Score: 0, Reward: 6.899999999999988, Steps done: 1867747
# Episode: 27680, Score: 0, Reward: 6.799999999999988, Steps done: 1867826
# Episode: 27681, Score: 5, Reward: 32.60000000000017, Steps done: 1868118
# Episode: 27682, Score: 3, Reward: 22.300000000000054, Steps done: 1868325
# Episode: 27683, Score: 1, Reward: 9.199999999999983, Steps done: 1868419
# Episode: 27684, Score: 3, Reward: 22.300000000000054, Steps done: 1868626
# Episode: 27685, Score: 7, Reward: 42.90000000000029, Steps done: 1869003
# Episode: 27686, Score: 0, Reward: 6.799999999999988, Steps done: 1869082
# Episode: 27687, Score: 0, Reward: 6.899999999999988, Steps done: 1869162
# Episode: 27688, Score: 2, Reward: 17.199999999999996, Steps done: 1869327
# Episode: 27689, Score: 0, Reward: 6.799999999999988, Steps done: 1869406
# Episode: 27690, Score: 2, Reward: 17.099999999999994, Steps done: 1869570
# Episode: 27691, Score: 0, Reward: 4.399999999999997, Steps done: 1869625
# Episode: 27692, Score: 1, Reward: 11.999999999999973, Steps done: 1869747
# Episode: 27693, Score: 2, Reward: 17.099999999999994, Steps done: 1869911
# Episode: 27694, Score: 16, Reward: 88.79999999999933, Steps done: 1870666
# Episode: 27695, Score: 0, Reward: 5.799999999999992, Steps done: 1870735
# Episode: 27696, Score: 1, Reward: 12.099999999999973, Steps done: 1870858
# Episode: 27697, Score: 0, Reward: 6.799999999999988, Steps done: 1870937
# Episode: 27698, Score: 1, Reward: 11.899999999999974, Steps done: 1871058
# Episode: 27699, Score: 0, Reward: 4.999999999999995, Steps done: 1871119
# Episode: 27700, Score: 0, Reward: 6.799999999999988, Steps done: 1871198
# Episode: 27701, Score: 0, Reward: 6.799999999999988, Steps done: 1871277
# Episode: 27702, Score: 2, Reward: 17.099999999999994, Steps done: 1871441
# Episode: 27703, Score: 2, Reward: 17.099999999999994, Steps done: 1871605
# Episode: 27704, Score: 5, Reward: 32.70000000000017, Steps done: 1871898
# Episode: 27705, Score: 5, Reward: 33.10000000000018, Steps done: 1872195
# Episode: 27706, Score: 4, Reward: 27.400000000000112, Steps done: 1872444
# Episode: 27707, Score: 0, Reward: 3.9999999999999982, Steps done: 1872495
# Episode: 27708, Score: 2, Reward: 14.299999999999969, Steps done: 1872631
# Episode: 27709, Score: 1, Reward: 12.69999999999997, Steps done: 1872760
# Episode: 27710, Score: 14, Reward: 76.29999999999993, Steps done: 1873408
# Episode: 27711, Score: 1, Reward: 11.899999999999974, Steps done: 1873529
# Episode: 27712, Score: 1, Reward: 11.899999999999974, Steps done: 1873650
# Episode: 27713, Score: 1, Reward: 12.399999999999972, Steps done: 1873776
# Episode: 27714, Score: 2, Reward: 14.199999999999969, Steps done: 1873911
# Episode: 27715, Score: 2, Reward: 17.099999999999994, Steps done: 1874075
# Episode: 27716, Score: 0, Reward: 6.799999999999988, Steps done: 1874154
# Episode: 27717, Score: 1, Reward: 8.999999999999984, Steps done: 1874246
# Episode: 27718, Score: 0, Reward: 5.699999999999992, Steps done: 1874314
# Episode: 27719, Score: 1, Reward: 11.999999999999973, Steps done: 1874436
# Episode: 27720, Score: 0, Reward: 6.999999999999988, Steps done: 1874517
# Episode: 27721, Score: 2, Reward: 17.099999999999994, Steps done: 1874681
# Episode: 27722, Score: 5, Reward: 32.60000000000017, Steps done: 1874973
# Episode: 27723, Score: 0, Reward: 6.19999999999999, Steps done: 1875046
# Episode: 27724, Score: 3, Reward: 19.80000000000002, Steps done: 1875228
# Episode: 27725, Score: 1, Reward: 11.899999999999974, Steps done: 1875349
# Episode: 27726, Score: 2, Reward: 17.099999999999994, Steps done: 1875513
# Episode: 27727, Score: 4, Reward: 27.400000000000112, Steps done: 1875762
# Episode: 27728, Score: 0, Reward: 6.099999999999991, Steps done: 1875834
# Episode: 27729, Score: 4, Reward: 28.300000000000125, Steps done: 1876092
# Episode: 27730, Score: 0, Reward: 6.099999999999991, Steps done: 1876164
# Episode: 27731, Score: 4, Reward: 24.600000000000072, Steps done: 1876385
# Episode: 27732, Score: 1, Reward: 9.499999999999982, Steps done: 1876482
# Episode: 27733, Score: 1, Reward: 11.899999999999974, Steps done: 1876603
# Episode: 27734, Score: 0, Reward: 6.899999999999988, Steps done: 1876683
# Episode: 27735, Score: 1, Reward: 9.499999999999982, Steps done: 1876780
# Episode: 27736, Score: 0, Reward: 6.999999999999988, Steps done: 1876861
# Episode: 27737, Score: 4, Reward: 27.400000000000112, Steps done: 1877110
# Episode: 27738, Score: 0, Reward: 6.799999999999988, Steps done: 1877189
# Episode: 27739, Score: 0, Reward: 5.099999999999994, Steps done: 1877251
# Episode: 27740, Score: 0, Reward: 6.799999999999988, Steps done: 1877330
# Episode: 27741, Score: 2, Reward: 17.099999999999994, Steps done: 1877494
# Episode: 27742, Score: 0, Reward: 5.399999999999993, Steps done: 1877559
# Episode: 27743, Score: 2, Reward: 14.199999999999969, Steps done: 1877694
# Episode: 27744, Score: 2, Reward: 17.199999999999996, Steps done: 1877859
# Episode: 27745, Score: 1, Reward: 11.899999999999974, Steps done: 1877980
# Episode: 27746, Score: 2, Reward: 17.800000000000004, Steps done: 1878151
# Episode: 27747, Score: 0, Reward: 6.799999999999988, Steps done: 1878230
# Episode: 27748, Score: 0, Reward: 6.799999999999988, Steps done: 1878309
# Episode: 27749, Score: 4, Reward: 27.800000000000118, Steps done: 1878562
# Episode: 27750, Score: 0, Reward: 6.799999999999988, Steps done: 1878641
# Episode: 27751, Score: 0, Reward: 6.499999999999989, Steps done: 1878717
# Episode: 27752, Score: 1, Reward: 12.199999999999973, Steps done: 1878841
# Episode: 27753, Score: 0, Reward: 5.499999999999993, Steps done: 1878907
# Episode: 27754, Score: 1, Reward: 11.899999999999974, Steps done: 1879028
# Episode: 27755, Score: 0, Reward: 5.8999999999999915, Steps done: 1879098
# Episode: 27756, Score: 0, Reward: 5.8999999999999915, Steps done: 1879168
# Episode: 27757, Score: 0, Reward: 4.399999999999997, Steps done: 1879223
# Episode: 27758, Score: 1, Reward: 9.299999999999983, Steps done: 1879318
# Episode: 27759, Score: 5, Reward: 29.800000000000132, Steps done: 1879582
# Episode: 27760, Score: 2, Reward: 17.099999999999994, Steps done: 1879746
# Episode: 27761, Score: 0, Reward: 6.799999999999988, Steps done: 1879825
# Episode: 27762, Score: 0, Reward: 5.199999999999994, Steps done: 1879888
# Episode: 27763, Score: 2, Reward: 14.299999999999969, Steps done: 1880024
# Episode: 27764, Score: 0, Reward: 5.099999999999994, Steps done: 1880086
# Episode: 27765, Score: 5, Reward: 33.10000000000018, Steps done: 1880383
# Episode: 27766, Score: 0, Reward: 6.899999999999988, Steps done: 1880463
# Episode: 27767, Score: 0, Reward: 7.199999999999987, Steps done: 1880546
# Episode: 27768, Score: 0, Reward: 6.999999999999988, Steps done: 1880627
# Episode: 27769, Score: 3, Reward: 22.300000000000054, Steps done: 1880834
# Episode: 27770, Score: 2, Reward: 17.099999999999994, Steps done: 1880998
# Episode: 27771, Score: 0, Reward: 6.799999999999988, Steps done: 1881077
# Episode: 27772, Score: 0, Reward: 6.799999999999988, Steps done: 1881156
# Episode: 27773, Score: 0, Reward: 6.999999999999988, Steps done: 1881237
# Episode: 27774, Score: 5, Reward: 29.800000000000132, Steps done: 1881501
# Episode: 27775, Score: 3, Reward: 19.500000000000014, Steps done: 1881680
# Episode: 27776, Score: 0, Reward: 6.899999999999988, Steps done: 1881760
# Episode: 27777, Score: 9, Reward: 53.20000000000041, Steps done: 1882222
# Episode: 27778, Score: 1, Reward: 12.89999999999997, Steps done: 1882353
# Episode: 27779, Score: 1, Reward: 11.999999999999973, Steps done: 1882475
# Episode: 27780, Score: 0, Reward: 6.799999999999988, Steps done: 1882554
# Episode: 27781, Score: 2, Reward: 17.099999999999994, Steps done: 1882718
# Episode: 27782, Score: 0, Reward: 6.799999999999988, Steps done: 1882797
# Episode: 27783, Score: 0, Reward: 5.399999999999993, Steps done: 1882862
# Episode: 27784, Score: 5, Reward: 32.60000000000017, Steps done: 1883154
# Episode: 27785, Score: 0, Reward: 4.399999999999997, Steps done: 1883209
# Episode: 27786, Score: 4, Reward: 24.800000000000075, Steps done: 1883432
# Episode: 27787, Score: 0, Reward: 5.499999999999993, Steps done: 1883498
# Episode: 27788, Score: 2, Reward: 17.199999999999996, Steps done: 1883663
# Episode: 27789, Score: 6, Reward: 35.4000000000002, Steps done: 1883974
# Episode: 27790, Score: 4, Reward: 27.400000000000112, Steps done: 1884223
# Episode: 27791, Score: 1, Reward: 9.199999999999983, Steps done: 1884317
# Episode: 27792, Score: 0, Reward: 4.399999999999997, Steps done: 1884372
# Episode: 27793, Score: 2, Reward: 14.899999999999967, Steps done: 1884514
# Episode: 27794, Score: 0, Reward: 4.799999999999995, Steps done: 1884573
# Episode: 27795, Score: 0, Reward: 7.899999999999984, Steps done: 1884663
# Episode: 27796, Score: 2, Reward: 14.199999999999969, Steps done: 1884798
# Episode: 27797, Score: 0, Reward: 6.799999999999988, Steps done: 1884877
# Episode: 27798, Score: 1, Reward: 11.999999999999973, Steps done: 1884999
# Episode: 27799, Score: 9, Reward: 53.20000000000041, Steps done: 1885461
# Episode: 27800, Score: 5, Reward: 29.70000000000013, Steps done: 1885724
# Episode: 27801, Score: 1, Reward: 11.899999999999974, Steps done: 1885845
# Episode: 27802, Score: 0, Reward: 7.2999999999999865, Steps done: 1885929
# Episode: 27803, Score: 0, Reward: 6.799999999999988, Steps done: 1886008
# Episode: 27804, Score: 0, Reward: 4.899999999999995, Steps done: 1886068
# Episode: 27805, Score: 0, Reward: 4.599999999999996, Steps done: 1886125
# Episode: 27806, Score: 0, Reward: 6.099999999999991, Steps done: 1886197
# Episode: 27807, Score: 0, Reward: 4.699999999999996, Steps done: 1886255
# Episode: 27808, Score: 0, Reward: 6.799999999999988, Steps done: 1886334
# Episode: 27809, Score: 1, Reward: 9.499999999999982, Steps done: 1886431
# Episode: 27810, Score: 0, Reward: 4.099999999999998, Steps done: 1886483
# Episode: 27811, Score: 2, Reward: 14.499999999999968, Steps done: 1886621
# Episode: 27812, Score: 0, Reward: 6.799999999999988, Steps done: 1886700
# Episode: 27813, Score: 0, Reward: 7.599999999999985, Steps done: 1886787
# Episode: 27814, Score: 1, Reward: 12.89999999999997, Steps done: 1886918
# Episode: 27815, Score: 0, Reward: 4.799999999999995, Steps done: 1886977
# Episode: 27816, Score: 1, Reward: 11.999999999999973, Steps done: 1887099
# Episode: 27817, Score: 0, Reward: 6.699999999999989, Steps done: 1887177
# Episode: 27818, Score: 1, Reward: 9.599999999999982, Steps done: 1887275
# Episode: 27819, Score: 1, Reward: 8.999999999999984, Steps done: 1887367
# Episode: 27820, Score: 0, Reward: 6.799999999999988, Steps done: 1887446
# Episode: 27821, Score: 1, Reward: 9.199999999999983, Steps done: 1887540
# Episode: 27822, Score: 2, Reward: 17.199999999999996, Steps done: 1887705
# Episode: 27823, Score: 5, Reward: 32.60000000000017, Steps done: 1887997
# Episode: 27824, Score: 1, Reward: 11.899999999999974, Steps done: 1888118
# Episode: 27825, Score: 1, Reward: 11.999999999999973, Steps done: 1888240
# Episode: 27826, Score: 0, Reward: 6.899999999999988, Steps done: 1888320
# Episode: 27827, Score: 0, Reward: 6.799999999999988, Steps done: 1888399
# Episode: 27828, Score: 3, Reward: 22.300000000000054, Steps done: 1888606
# Episode: 27829, Score: 5, Reward: 32.60000000000017, Steps done: 1888898
# Episode: 27830, Score: 1, Reward: 12.099999999999973, Steps done: 1889021
# Episode: 27831, Score: 2, Reward: 17.099999999999994, Steps done: 1889185
# Episode: 27832, Score: 3, Reward: 22.300000000000054, Steps done: 1889392
# Episode: 27833, Score: 11, Reward: 60.600000000000485, Steps done: 1889910
# Episode: 27834, Score: 2, Reward: 17.099999999999994, Steps done: 1890074
# Episode: 27835, Score: 1, Reward: 12.89999999999997, Steps done: 1890205
# Episode: 27836, Score: 0, Reward: 6.799999999999988, Steps done: 1890284
# Episode: 27837, Score: 7, Reward: 42.90000000000029, Steps done: 1890661
# Episode: 27838, Score: 5, Reward: 33.30000000000018, Steps done: 1890960
# Episode: 27839, Score: 6, Reward: 37.70000000000023, Steps done: 1891294
# Episode: 27840, Score: 1, Reward: 9.399999999999983, Steps done: 1891390
# Episode: 27841, Score: 2, Reward: 14.599999999999968, Steps done: 1891529
# Episode: 27842, Score: 2, Reward: 14.799999999999967, Steps done: 1891670
# Episode: 27843, Score: 0, Reward: 6.799999999999988, Steps done: 1891749
# Episode: 27844, Score: 3, Reward: 19.600000000000016, Steps done: 1891929
# Episode: 27845, Score: 10, Reward: 59.10000000000048, Steps done: 1892441
# Episode: 27846, Score: 1, Reward: 12.69999999999997, Steps done: 1892570
# Episode: 27847, Score: 9, Reward: 53.20000000000041, Steps done: 1893032
# Episode: 27848, Score: 0, Reward: 6.799999999999988, Steps done: 1893111
# Episode: 27849, Score: 1, Reward: 11.999999999999973, Steps done: 1893233
# Episode: 27850, Score: 0, Reward: 0.5000000000000002, Steps done: 1893249
# Episode: 27851, Score: 0, Reward: 6.799999999999988, Steps done: 1893328
# Episode: 27852, Score: 2, Reward: 16.999999999999993, Steps done: 1893491
# Episode: 27853, Score: 2, Reward: 14.499999999999968, Steps done: 1893629
# Episode: 27854, Score: 0, Reward: 7.799999999999985, Steps done: 1893718
# Episode: 27855, Score: 0, Reward: 6.899999999999988, Steps done: 1893798
# Episode: 27856, Score: 0, Reward: 7.199999999999987, Steps done: 1893881
# Episode: 27857, Score: 3, Reward: 22.60000000000006, Steps done: 1894091
# Episode: 27858, Score: 1, Reward: 11.899999999999974, Steps done: 1894212
# Episode: 27859, Score: 1, Reward: 11.999999999999973, Steps done: 1894334
# Episode: 27860, Score: 2, Reward: 17.099999999999994, Steps done: 1894498
# Episode: 27861, Score: 0, Reward: 4.399999999999997, Steps done: 1894553
# Episode: 27862, Score: 3, Reward: 22.300000000000054, Steps done: 1894760
# Episode: 27863, Score: 1, Reward: 9.299999999999983, Steps done: 1894855
# Episode: 27864, Score: 1, Reward: 12.69999999999997, Steps done: 1894984
# Episode: 27865, Score: 1, Reward: 9.699999999999982, Steps done: 1895083
# Episode: 27866, Score: 0, Reward: 6.799999999999988, Steps done: 1895162
# Episode: 27867, Score: 1, Reward: 11.999999999999973, Steps done: 1895284
# Episode: 27868, Score: 5, Reward: 32.60000000000017, Steps done: 1895576
# Episode: 27869, Score: 0, Reward: 4.699999999999996, Steps done: 1895634
# Episode: 27870, Score: 1, Reward: 12.199999999999973, Steps done: 1895758
# Episode: 27871, Score: 1, Reward: 11.899999999999974, Steps done: 1895879
# Episode: 27872, Score: 1, Reward: 11.999999999999973, Steps done: 1896001
# Episode: 27873, Score: 0, Reward: 6.799999999999988, Steps done: 1896080
# Episode: 27874, Score: 0, Reward: 3.1000000000000014, Steps done: 1896122
# Episode: 27875, Score: 2, Reward: 17.6, Steps done: 1896291
# Episode: 27876, Score: 5, Reward: 32.60000000000017, Steps done: 1896583
# Episode: 27877, Score: 3, Reward: 22.400000000000055, Steps done: 1896791
# Episode: 27878, Score: 1, Reward: 11.999999999999973, Steps done: 1896913
# Episode: 27879, Score: 0, Reward: 6.799999999999988, Steps done: 1896992
# Episode: 27880, Score: 2, Reward: 14.599999999999968, Steps done: 1897131
# Episode: 27881, Score: 1, Reward: 8.999999999999984, Steps done: 1897223
# Episode: 27882, Score: 0, Reward: 6.799999999999988, Steps done: 1897302
# Episode: 27883, Score: 5, Reward: 32.900000000000176, Steps done: 1897597
# Episode: 27884, Score: 1, Reward: 11.899999999999974, Steps done: 1897718
# Episode: 27885, Score: 0, Reward: 6.799999999999988, Steps done: 1897797
# Episode: 27886, Score: 2, Reward: 17.099999999999994, Steps done: 1897961
# Episode: 27887, Score: 2, Reward: 17.099999999999994, Steps done: 1898125
# Episode: 27888, Score: 12, Reward: 66.20000000000039, Steps done: 1898690
# Episode: 27889, Score: 2, Reward: 18.20000000000001, Steps done: 1898865
# Episode: 27890, Score: 1, Reward: 9.399999999999983, Steps done: 1898961
# Episode: 27891, Score: 5, Reward: 30.200000000000138, Steps done: 1899229
# Episode: 27892, Score: 1, Reward: 8.999999999999984, Steps done: 1899321
# Episode: 27893, Score: 0, Reward: 6.799999999999988, Steps done: 1899400
# Episode: 27894, Score: 2, Reward: 17.900000000000006, Steps done: 1899572
# Episode: 27895, Score: 2, Reward: 17.099999999999994, Steps done: 1899736
# Episode: 27896, Score: 2, Reward: 14.499999999999968, Steps done: 1899874
# Episode: 27897, Score: 0, Reward: 5.5999999999999925, Steps done: 1899941
# Episode: 27898, Score: 3, Reward: 22.200000000000053, Steps done: 1900147
# Episode: 27899, Score: 6, Reward: 37.70000000000023, Steps done: 1900481
# Episode: 27900, Score: 2, Reward: 17.199999999999996, Steps done: 1900646
# Episode: 27901, Score: 2, Reward: 17.5, Steps done: 1900814
# Episode: 27902, Score: 0, Reward: 6.799999999999988, Steps done: 1900893
# Episode: 27903, Score: 0, Reward: 4.4999999999999964, Steps done: 1900949
# Episode: 27904, Score: 0, Reward: 6.799999999999988, Steps done: 1901028
# Episode: 27905, Score: 3, Reward: 20.70000000000003, Steps done: 1901219
# Episode: 27906, Score: 0, Reward: 6.799999999999988, Steps done: 1901298
# Episode: 27907, Score: 2, Reward: 17.099999999999994, Steps done: 1901462
# Episode: 27908, Score: 1, Reward: 12.199999999999973, Steps done: 1901586
# Episode: 27909, Score: 4, Reward: 27.400000000000112, Steps done: 1901835
# Episode: 27910, Score: 4, Reward: 27.400000000000112, Steps done: 1902084
# Episode: 27911, Score: 0, Reward: 6.799999999999988, Steps done: 1902163
# Episode: 27912, Score: 6, Reward: 34.90000000000019, Steps done: 1902469
# Episode: 27913, Score: 2, Reward: 17.099999999999994, Steps done: 1902633
# Episode: 27914, Score: 7, Reward: 42.90000000000029, Steps done: 1903010
# Episode: 27915, Score: 1, Reward: 12.89999999999997, Steps done: 1903141
# Episode: 27916, Score: 2, Reward: 13.199999999999969, Steps done: 1903275
# Episode: 27917, Score: 6, Reward: 37.70000000000023, Steps done: 1903609
# Episode: 27918, Score: 2, Reward: 17.700000000000003, Steps done: 1903779
# Episode: 27919, Score: 4, Reward: 27.600000000000115, Steps done: 1904030
# Episode: 27920, Score: 1, Reward: 9.099999999999984, Steps done: 1904123
# Episode: 27921, Score: 0, Reward: 4.399999999999997, Steps done: 1904178
# Episode: 27922, Score: 0, Reward: 6.799999999999988, Steps done: 1904257
# Episode: 27923, Score: 1, Reward: 8.999999999999984, Steps done: 1904349
# Episode: 27924, Score: 2, Reward: 15.499999999999972, Steps done: 1904497
# Episode: 27925, Score: 2, Reward: 17.099999999999994, Steps done: 1904661
# Episode: 27926, Score: 1, Reward: 11.899999999999974, Steps done: 1904782
# Episode: 27927, Score: 1, Reward: 11.999999999999973, Steps done: 1904904
# Episode: 27928, Score: 0, Reward: 6.799999999999988, Steps done: 1904983
# Episode: 27929, Score: 1, Reward: 12.199999999999973, Steps done: 1905107
# Episode: 27930, Score: 0, Reward: 3.799999999999999, Steps done: 1905156
# Episode: 27931, Score: 3, Reward: 22.300000000000054, Steps done: 1905363
# Episode: 27932, Score: 0, Reward: 3.6999999999999993, Steps done: 1905411
# Episode: 27933, Score: 0, Reward: 6.999999999999988, Steps done: 1905492
# Episode: 27934, Score: 1, Reward: 9.499999999999982, Steps done: 1905589
# Episode: 27935, Score: 2, Reward: 17.099999999999994, Steps done: 1905753
# Episode: 27936, Score: 6, Reward: 34.80000000000019, Steps done: 1906058
# Episode: 27937, Score: 0, Reward: 6.799999999999988, Steps done: 1906137
# Episode: 27938, Score: 8, Reward: 48.00000000000035, Steps done: 1906556
# Episode: 27939, Score: 0, Reward: 4.399999999999997, Steps done: 1906611
# Episode: 27940, Score: 0, Reward: 7.699999999999985, Steps done: 1906699
# Episode: 27941, Score: 2, Reward: 17.4, Steps done: 1906866
# Episode: 27942, Score: 5, Reward: 32.60000000000017, Steps done: 1907158
# Episode: 27943, Score: 0, Reward: 6.799999999999988, Steps done: 1907237
# Episode: 27944, Score: 1, Reward: 11.999999999999973, Steps done: 1907359
# Episode: 27945, Score: 7, Reward: 42.90000000000029, Steps done: 1907736
# Episode: 27946, Score: 5, Reward: 32.60000000000017, Steps done: 1908028
# Episode: 27947, Score: 4, Reward: 27.400000000000112, Steps done: 1908277
# Episode: 27948, Score: 1, Reward: 11.899999999999974, Steps done: 1908398
# Episode: 27949, Score: 3, Reward: 22.300000000000054, Steps done: 1908605
# Episode: 27950, Score: 1, Reward: 12.79999999999997, Steps done: 1908735
# Episode: 27951, Score: 2, Reward: 17.099999999999994, Steps done: 1908899
# Episode: 27952, Score: 1, Reward: 12.499999999999972, Steps done: 1909026
# Episode: 27953, Score: 2, Reward: 17.099999999999994, Steps done: 1909190
# Episode: 27954, Score: 1, Reward: 8.999999999999984, Steps done: 1909282
# Episode: 27955, Score: 5, Reward: 32.60000000000017, Steps done: 1909574
# Episode: 27956, Score: 1, Reward: 11.899999999999974, Steps done: 1909695
# Episode: 27957, Score: 5, Reward: 32.800000000000175, Steps done: 1909989
# Episode: 27958, Score: 1, Reward: 11.899999999999974, Steps done: 1910110
# Episode: 27959, Score: 0, Reward: 6.799999999999988, Steps done: 1910189
# Episode: 27960, Score: 1, Reward: 11.899999999999974, Steps done: 1910310
# Episode: 27961, Score: 1, Reward: 11.899999999999974, Steps done: 1910431
# Episode: 27962, Score: 1, Reward: 9.399999999999983, Steps done: 1910527
# Episode: 27963, Score: 2, Reward: 13.199999999999969, Steps done: 1910661
# Episode: 27964, Score: 1, Reward: 11.899999999999974, Steps done: 1910782
# Episode: 27965, Score: 4, Reward: 27.400000000000112, Steps done: 1911031
# Episode: 27966, Score: 2, Reward: 17.099999999999994, Steps done: 1911195
# Episode: 27967, Score: 0, Reward: 6.799999999999988, Steps done: 1911274
# Episode: 27968, Score: 5, Reward: 32.70000000000017, Steps done: 1911567
# Episode: 27969, Score: 1, Reward: 11.899999999999974, Steps done: 1911688
# Episode: 27970, Score: 2, Reward: 17.099999999999994, Steps done: 1911852
# Episode: 27971, Score: 3, Reward: 22.300000000000054, Steps done: 1912059
# Episode: 27972, Score: 0, Reward: 4.099999999999998, Steps done: 1912111
# Episode: 27973, Score: 0, Reward: 7.799999999999985, Steps done: 1912200
# Episode: 27974, Score: 2, Reward: 17.099999999999994, Steps done: 1912364
# Episode: 27975, Score: 4, Reward: 24.50000000000007, Steps done: 1912584
# Episode: 27976, Score: 0, Reward: 4.599999999999996, Steps done: 1912641
# Episode: 27977, Score: 0, Reward: 4.299999999999997, Steps done: 1912695
# Episode: 27978, Score: 4, Reward: 27.400000000000112, Steps done: 1912944
# Episode: 27979, Score: 5, Reward: 32.60000000000017, Steps done: 1913236
# Episode: 27980, Score: 4, Reward: 27.600000000000115, Steps done: 1913487
# Episode: 27981, Score: 6, Reward: 37.70000000000023, Steps done: 1913821
# Episode: 27982, Score: 0, Reward: 6.999999999999988, Steps done: 1913902
# Episode: 27983, Score: 0, Reward: 6.799999999999988, Steps done: 1913981
# Episode: 27984, Score: 0, Reward: 3.9999999999999982, Steps done: 1914032
# Episode: 27985, Score: 2, Reward: 17.099999999999994, Steps done: 1914196
# Episode: 27986, Score: 0, Reward: 6.099999999999991, Steps done: 1914268
# Episode: 27987, Score: 3, Reward: 19.700000000000017, Steps done: 1914449
# Episode: 27988, Score: 8, Reward: 48.20000000000035, Steps done: 1914870
# Episode: 27989, Score: 3, Reward: 22.300000000000054, Steps done: 1915077
# Episode: 27990, Score: 1, Reward: 9.399999999999983, Steps done: 1915173
# Episode: 27991, Score: 7, Reward: 40.10000000000025, Steps done: 1915522
# Episode: 27992, Score: 0, Reward: 6.799999999999988, Steps done: 1915601
# Episode: 27993, Score: 0, Reward: 4.899999999999995, Steps done: 1915661
# Episode: 27994, Score: 3, Reward: 22.300000000000054, Steps done: 1915868
# Episode: 27995, Score: 1, Reward: 9.199999999999983, Steps done: 1915962
# Episode: 27996, Score: 2, Reward: 17.199999999999996, Steps done: 1916127
# Episode: 27997, Score: 2, Reward: 14.599999999999968, Steps done: 1916266
# Episode: 27998, Score: 4, Reward: 25.10000000000008, Steps done: 1916492
# Episode: 27999, Score: 4, Reward: 27.500000000000114, Steps done: 1916742
# Episode: 28000, Score: 4, Reward: 27.500000000000114, Steps done: 1916992
# Episode: 28001, Score: 0, Reward: 6.799999999999988, Steps done: 1917071
# Episode: 28002, Score: 2, Reward: 16.999999999999993, Steps done: 1917234
# Episode: 28003, Score: 1, Reward: 11.999999999999973, Steps done: 1917356
# Episode: 28004, Score: 1, Reward: 12.199999999999973, Steps done: 1917480
# Episode: 28005, Score: 2, Reward: 14.599999999999968, Steps done: 1917619
# Episode: 28006, Score: 1, Reward: 9.499999999999982, Steps done: 1917716
# Episode: 28007, Score: 7, Reward: 39.90000000000025, Steps done: 1918063
# Episode: 28008, Score: 2, Reward: 17.099999999999994, Steps done: 1918227
# Episode: 28009, Score: 1, Reward: 11.899999999999974, Steps done: 1918348
# Episode: 28010, Score: 0, Reward: 4.599999999999996, Steps done: 1918405
# Episode: 28011, Score: 2, Reward: 17.199999999999996, Steps done: 1918570
# Episode: 28012, Score: 2, Reward: 17.099999999999994, Steps done: 1918734
# Episode: 28013, Score: 4, Reward: 24.900000000000077, Steps done: 1918958
# Episode: 28014, Score: 0, Reward: 6.999999999999988, Steps done: 1919039
# Episode: 28015, Score: 1, Reward: 9.299999999999983, Steps done: 1919134
# Episode: 28016, Score: 3, Reward: 22.300000000000054, Steps done: 1919341
# Episode: 28017, Score: 2, Reward: 17.199999999999996, Steps done: 1919506
# Episode: 28018, Score: 2, Reward: 17.099999999999994, Steps done: 1919670
# Episode: 28019, Score: 1, Reward: 11.999999999999973, Steps done: 1919792
# Episode: 28020, Score: 0, Reward: 6.799999999999988, Steps done: 1919871
# Episode: 28021, Score: 2, Reward: 17.099999999999994, Steps done: 1920035
# Episode: 28022, Score: 0, Reward: 6.899999999999988, Steps done: 1920115
# Episode: 28023, Score: 0, Reward: 6.999999999999988, Steps done: 1920196
# Episode: 28024, Score: 0, Reward: 6.799999999999988, Steps done: 1920275
# Episode: 28025, Score: 0, Reward: 7.2999999999999865, Steps done: 1920359
# Episode: 28026, Score: 5, Reward: 32.50000000000017, Steps done: 1920650
# Episode: 28027, Score: 1, Reward: 8.999999999999984, Steps done: 1920742
# Episode: 28028, Score: 0, Reward: 7.199999999999987, Steps done: 1920825
# Episode: 28029, Score: 1, Reward: 11.999999999999973, Steps done: 1920947
# Episode: 28030, Score: 0, Reward: 6.799999999999988, Steps done: 1921026
# Episode: 28031, Score: 0, Reward: 7.399999999999986, Steps done: 1921111
# Episode: 28032, Score: 0, Reward: 4.4999999999999964, Steps done: 1921167
# Episode: 28033, Score: 1, Reward: 9.199999999999983, Steps done: 1921261
# Episode: 28034, Score: 0, Reward: 6.799999999999988, Steps done: 1921340
# Episode: 28035, Score: 12, Reward: 68.60000000000025, Steps done: 1921929
# Episode: 28036, Score: 1, Reward: 11.899999999999974, Steps done: 1922050
# Episode: 28037, Score: 1, Reward: 9.499999999999982, Steps done: 1922147
# Episode: 28038, Score: 2, Reward: 14.899999999999967, Steps done: 1922289
# Episode: 28039, Score: 5, Reward: 29.800000000000132, Steps done: 1922553
# Episode: 28040, Score: 0, Reward: 0.5000000000000002, Steps done: 1922569
# Episode: 28041, Score: 4, Reward: 27.400000000000112, Steps done: 1922818
# Episode: 28042, Score: 7, Reward: 42.90000000000029, Steps done: 1923195
# Episode: 28043, Score: 8, Reward: 48.90000000000036, Steps done: 1923623
# Episode: 28044, Score: 5, Reward: 32.60000000000017, Steps done: 1923915
# Episode: 28045, Score: 2, Reward: 17.099999999999994, Steps done: 1924079
# Episode: 28046, Score: 1, Reward: 11.999999999999973, Steps done: 1924201
# Episode: 28047, Score: 0, Reward: 6.899999999999988, Steps done: 1924281
# Episode: 28048, Score: 1, Reward: 11.999999999999973, Steps done: 1924403
# Episode: 28049, Score: 0, Reward: 6.799999999999988, Steps done: 1924482
# Episode: 28050, Score: 1, Reward: 12.399999999999972, Steps done: 1924608
# Episode: 28051, Score: 2, Reward: 17.099999999999994, Steps done: 1924772
# Episode: 28052, Score: 2, Reward: 14.199999999999969, Steps done: 1924907
# Episode: 28053, Score: 6, Reward: 37.70000000000023, Steps done: 1925241
# Episode: 28054, Score: 2, Reward: 17.099999999999994, Steps done: 1925405
# Episode: 28055, Score: 2, Reward: 17.4, Steps done: 1925572
# Episode: 28056, Score: 4, Reward: 27.400000000000112, Steps done: 1925821
# Episode: 28057, Score: 0, Reward: 6.799999999999988, Steps done: 1925900
# Episode: 28058, Score: 1, Reward: 9.099999999999984, Steps done: 1925993
# Episode: 28059, Score: 5, Reward: 32.900000000000176, Steps done: 1926288
# Episode: 28060, Score: 4, Reward: 28.500000000000128, Steps done: 1926548
# Episode: 28061, Score: 8, Reward: 45.20000000000031, Steps done: 1926939
# Episode: 28062, Score: 1, Reward: 11.999999999999973, Steps done: 1927061
# Episode: 28063, Score: 0, Reward: 6.899999999999988, Steps done: 1927141
# Episode: 28064, Score: 1, Reward: 8.999999999999984, Steps done: 1927233
# Episode: 28065, Score: 0, Reward: 6.799999999999988, Steps done: 1927312
# Episode: 28066, Score: 1, Reward: 11.899999999999974, Steps done: 1927433
# Episode: 28067, Score: 0, Reward: 0.5000000000000002, Steps done: 1927449
# Episode: 28068, Score: 4, Reward: 27.30000000000011, Steps done: 1927697
# Episode: 28069, Score: 0, Reward: 4.399999999999997, Steps done: 1927752
# Episode: 28070, Score: 0, Reward: 6.799999999999988, Steps done: 1927831
# Episode: 28071, Score: 2, Reward: 16.999999999999993, Steps done: 1927994
# Episode: 28072, Score: 1, Reward: 9.299999999999983, Steps done: 1928089
# Episode: 28073, Score: 1, Reward: 12.499999999999972, Steps done: 1928216
# Episode: 28074, Score: 0, Reward: 6.999999999999988, Steps done: 1928297
# Episode: 28075, Score: 1, Reward: 11.999999999999973, Steps done: 1928419
# Episode: 28076, Score: 1, Reward: 11.899999999999974, Steps done: 1928540
# Episode: 28077, Score: 0, Reward: 7.699999999999985, Steps done: 1928628
# Episode: 28078, Score: 4, Reward: 27.500000000000114, Steps done: 1928878
# Episode: 28079, Score: 1, Reward: 12.099999999999973, Steps done: 1929001
# Episode: 28080, Score: 1, Reward: 11.899999999999974, Steps done: 1929122
# Episode: 28081, Score: 2, Reward: 17.099999999999994, Steps done: 1929286
# Episode: 28082, Score: 10, Reward: 55.60000000000043, Steps done: 1929763
# Episode: 28083, Score: 2, Reward: 17.099999999999994, Steps done: 1929927
# Episode: 28084, Score: 1, Reward: 11.999999999999973, Steps done: 1930049
# Episode: 28085, Score: 1, Reward: 11.899999999999974, Steps done: 1930170
# Episode: 28086, Score: 2, Reward: 17.099999999999994, Steps done: 1930334
# Episode: 28087, Score: 0, Reward: 7.799999999999985, Steps done: 1930423
# Episode: 28088, Score: 1, Reward: 8.999999999999984, Steps done: 1930515
# Episode: 28089, Score: 2, Reward: 17.099999999999994, Steps done: 1930679
# Episode: 28090, Score: 2, Reward: 17.099999999999994, Steps done: 1930843
# Episode: 28091, Score: 4, Reward: 28.100000000000122, Steps done: 1931099
# Episode: 28092, Score: 0, Reward: 4.4999999999999964, Steps done: 1931155
# Episode: 28093, Score: 1, Reward: 9.299999999999983, Steps done: 1931250
# Episode: 28094, Score: 5, Reward: 32.60000000000017, Steps done: 1931542
# Episode: 28095, Score: 3, Reward: 22.300000000000054, Steps done: 1931749
# Episode: 28096, Score: 2, Reward: 17.099999999999994, Steps done: 1931913
# Episode: 28097, Score: 4, Reward: 24.900000000000077, Steps done: 1932137
# Episode: 28098, Score: 5, Reward: 29.60000000000013, Steps done: 1932399
# Episode: 28099, Score: 0, Reward: 6.799999999999988, Steps done: 1932478
# Episode: 28100, Score: 1, Reward: 9.499999999999982, Steps done: 1932575
# Episode: 28101, Score: 2, Reward: 17.099999999999994, Steps done: 1932739
# Episode: 28102, Score: 1, Reward: 12.199999999999973, Steps done: 1932863
# Episode: 28103, Score: 1, Reward: 11.899999999999974, Steps done: 1932984
# Episode: 28104, Score: 1, Reward: 12.299999999999972, Steps done: 1933109
# Episode: 28105, Score: 0, Reward: 0.5000000000000002, Steps done: 1933125
# Episode: 28106, Score: 0, Reward: 4.399999999999997, Steps done: 1933180
# Episode: 28107, Score: 5, Reward: 33.00000000000018, Steps done: 1933476
# Episode: 28108, Score: 3, Reward: 22.300000000000054, Steps done: 1933683
# Episode: 28109, Score: 3, Reward: 23.200000000000067, Steps done: 1933899
# Episode: 28110, Score: 2, Reward: 17.099999999999994, Steps done: 1934063
# Episode: 28111, Score: 2, Reward: 17.099999999999994, Steps done: 1934227
# Episode: 28112, Score: 0, Reward: 6.799999999999988, Steps done: 1934306
# Episode: 28113, Score: 0, Reward: 6.999999999999988, Steps done: 1934387
# Episode: 28114, Score: 3, Reward: 18.30000000000001, Steps done: 1934563
# Episode: 28115, Score: 12, Reward: 68.60000000000025, Steps done: 1935152
# Episode: 28116, Score: 0, Reward: 7.099999999999987, Steps done: 1935234
# Episode: 28117, Score: 3, Reward: 22.200000000000053, Steps done: 1935440
# Episode: 28118, Score: 2, Reward: 17.199999999999996, Steps done: 1935605
# Episode: 28119, Score: 2, Reward: 17.099999999999994, Steps done: 1935769
# Episode: 28120, Score: 3, Reward: 22.300000000000054, Steps done: 1935976
# Episode: 28121, Score: 0, Reward: 6.799999999999988, Steps done: 1936055
# Episode: 28122, Score: 0, Reward: 7.699999999999985, Steps done: 1936143
# Episode: 28123, Score: 4, Reward: 27.500000000000114, Steps done: 1936393
# Episode: 28124, Score: 0, Reward: 7.499999999999986, Steps done: 1936479
# Episode: 28125, Score: 2, Reward: 18.10000000000001, Steps done: 1936653
# Episode: 28126, Score: 0, Reward: 6.899999999999988, Steps done: 1936733
# Episode: 28127, Score: 4, Reward: 28.300000000000125, Steps done: 1936991
# Episode: 28128, Score: 0, Reward: 7.899999999999984, Steps done: 1937081
# Episode: 28129, Score: 4, Reward: 27.400000000000112, Steps done: 1937330
# Episode: 28130, Score: 2, Reward: 17.099999999999994, Steps done: 1937494
# Episode: 28131, Score: 0, Reward: 4.399999999999997, Steps done: 1937549
# Episode: 28132, Score: 2, Reward: 18.20000000000001, Steps done: 1937724
# Episode: 28133, Score: 8, Reward: 45.20000000000031, Steps done: 1938115
# Episode: 28134, Score: 0, Reward: 6.799999999999988, Steps done: 1938194
# Episode: 28135, Score: 2, Reward: 17.199999999999996, Steps done: 1938359
# Episode: 28136, Score: 0, Reward: 0.5000000000000002, Steps done: 1938375
# Episode: 28137, Score: 6, Reward: 34.90000000000019, Steps done: 1938681
# Episode: 28138, Score: 2, Reward: 17.099999999999994, Steps done: 1938845
# Episode: 28139, Score: 2, Reward: 14.199999999999969, Steps done: 1938980
# Episode: 28140, Score: 2, Reward: 17.299999999999997, Steps done: 1939146
# Episode: 28141, Score: 9, Reward: 53.20000000000041, Steps done: 1939608
# Episode: 28142, Score: 2, Reward: 17.099999999999994, Steps done: 1939772
# Episode: 28143, Score: 0, Reward: 6.899999999999988, Steps done: 1939852
# Episode: 28144, Score: 3, Reward: 22.60000000000006, Steps done: 1940062
# Episode: 28145, Score: 0, Reward: 6.899999999999988, Steps done: 1940142
# Episode: 28146, Score: 0, Reward: 6.799999999999988, Steps done: 1940221
# Episode: 28147, Score: 5, Reward: 32.50000000000017, Steps done: 1940512
# Episode: 28148, Score: 0, Reward: 6.799999999999988, Steps done: 1940591
# Episode: 28149, Score: 1, Reward: 7.999999999999984, Steps done: 1940682
# Episode: 28150, Score: 0, Reward: 4.699999999999996, Steps done: 1940740
# Episode: 28151, Score: 7, Reward: 40.10000000000025, Steps done: 1941089
# Episode: 28152, Score: 2, Reward: 17.099999999999994, Steps done: 1941253
# Episode: 28153, Score: 0, Reward: 6.799999999999988, Steps done: 1941332
# Episode: 28154, Score: 1, Reward: 11.899999999999974, Steps done: 1941453
# ...
# Episode: 29802, Score: 0, Reward: 0.5000000000000002, Steps done: 2223042
# Episode: 29803, Score: 4, Reward: 24.900000000000077, Steps done: 2223266
# Episode: 29804, Score: 4, Reward: 28.00000000000012, Steps done: 2223521
# Episode: 29805, Score: 6, Reward: 37.60000000000023, Steps done: 2223854
# Episode: 29806, Score: 3, Reward: 19.90000000000002, Steps done: 2224037
# Episode: 29807, Score: 1, Reward: 12.199999999999973, Steps done: 2224161
# Episode: 29808, Score: 2, Reward: 14.199999999999969, Steps done: 2224296
# Episode: 29809, Score: 2, Reward: 14.699999999999967, Steps done: 2224436
# Episode: 29810, Score: 3, Reward: 22.200000000000053, Steps done: 2224642
# Episode: 29811, Score: 2, Reward: 17.099999999999994, Steps done: 2224806
# Episode: 29812, Score: 3, Reward: 22.300000000000054, Steps done: 2225013
# Episode: 29813, Score: 6, Reward: 35.00000000000019, Steps done: 2225320
# Episode: 29814, Score: 1, Reward: 9.699999999999982, Steps done: 2225419
# Episode: 29815, Score: 1, Reward: 12.099999999999973, Steps done: 2225542
# Episode: 29816, Score: 5, Reward: 32.60000000000017, Steps done: 2225834
# Episode: 29817, Score: 3, Reward: 19.600000000000016, Steps done: 2226014
# Episode: 29818, Score: 3, Reward: 22.300000000000054, Steps done: 2226221
# Episode: 29819, Score: 1, Reward: 9.599999999999982, Steps done: 2226319
# Episode: 29820, Score: 2, Reward: 17.6, Steps done: 2226488
# Episode: 29821, Score: 4, Reward: 27.400000000000112, Steps done: 2226737
# Episode: 29822, Score: 1, Reward: 8.999999999999984, Steps done: 2226829
# Episode: 29823, Score: 1, Reward: 12.89999999999997, Steps done: 2226960
# Episode: 29824, Score: 1, Reward: 9.199999999999983, Steps done: 2227054
# Episode: 29825, Score: 8, Reward: 48.00000000000035, Steps done: 2227473
# Episode: 29826, Score: 1, Reward: 9.199999999999983, Steps done: 2227567
# Episode: 29827, Score: 2, Reward: 17.099999999999994, Steps done: 2227731
# Episode: 29828, Score: 4, Reward: 27.400000000000112, Steps done: 2227980
# Episode: 29829, Score: 4, Reward: 24.600000000000072, Steps done: 2228201
# Episode: 29830, Score: 0, Reward: 6.899999999999988, Steps done: 2228281
# Episode: 29831, Score: 0, Reward: 6.799999999999988, Steps done: 2228360
# Episode: 29832, Score: 0, Reward: 7.799999999999985, Steps done: 2228449
# Episode: 29833, Score: 1, Reward: 11.999999999999973, Steps done: 2228571
# Episode: 29834, Score: 1, Reward: 9.699999999999982, Steps done: 2228670
# Episode: 29835, Score: 8, Reward: 45.30000000000031, Steps done: 2229062
# Episode: 29836, Score: 2, Reward: 17.4, Steps done: 2229229
# Episode: 29837, Score: 1, Reward: 11.999999999999973, Steps done: 2229351
# Episode: 29838, Score: 2, Reward: 17.900000000000006, Steps done: 2229523
# Episode: 29839, Score: 3, Reward: 22.400000000000055, Steps done: 2229731
# Episode: 29840, Score: 1, Reward: 11.899999999999974, Steps done: 2229852
# Episode: 29841, Score: 2, Reward: 17.099999999999994, Steps done: 2230016
# Episode: 29842, Score: 4, Reward: 28.100000000000122, Steps done: 2230272
# Episode: 29843, Score: 3, Reward: 19.30000000000001, Steps done: 2230449
# Episode: 29844, Score: 2, Reward: 18.20000000000001, Steps done: 2230624
# Episode: 29845, Score: 10, Reward: 59.10000000000048, Steps done: 2231136
# Episode: 29846, Score: 2, Reward: 17.199999999999996, Steps done: 2231301
# Episode: 29847, Score: 0, Reward: 0.5000000000000002, Steps done: 2231317
# Episode: 29848, Score: 1, Reward: 12.99999999999997, Steps done: 2231449
# Episode: 29849, Score: 1, Reward: 11.999999999999973, Steps done: 2231571
# Episode: 29850, Score: 2, Reward: 17.099999999999994, Steps done: 2231735
# Episode: 29851, Score: 2, Reward: 16.999999999999993, Steps done: 2231898
# Episode: 29852, Score: 2, Reward: 17.099999999999994, Steps done: 2232062
# Episode: 29853, Score: 4, Reward: 27.400000000000112, Steps done: 2232311
# Episode: 29854, Score: 1, Reward: 12.499999999999972, Steps done: 2232438
# Episode: 29855, Score: 0, Reward: 6.799999999999988, Steps done: 2232517
# Episode: 29856, Score: 1, Reward: 11.899999999999974, Steps done: 2232638
# Episode: 29857, Score: 8, Reward: 45.600000000000314, Steps done: 2233033
# Episode: 29858, Score: 4, Reward: 27.400000000000112, Steps done: 2233282
# Episode: 29859, Score: 3, Reward: 22.70000000000006, Steps done: 2233493
# Episode: 29860, Score: 0, Reward: 6.799999999999988, Steps done: 2233572
# Episode: 29861, Score: 2, Reward: 14.699999999999967, Steps done: 2233712
# Episode: 29862, Score: 1, Reward: 11.899999999999974, Steps done: 2233833
# Episode: 29863, Score: 4, Reward: 27.400000000000112, Steps done: 2234082
# Episode: 29864, Score: 0, Reward: 6.799999999999988, Steps done: 2234161
# Episode: 29865, Score: 2, Reward: 17.099999999999994, Steps done: 2234325
# Episode: 29866, Score: 1, Reward: 11.999999999999973, Steps done: 2234447
# Episode: 29867, Score: 0, Reward: 6.799999999999988, Steps done: 2234526
# Episode: 29868, Score: 0, Reward: 0.5000000000000002, Steps done: 2234542
# Episode: 29869, Score: 0, Reward: 7.399999999999986, Steps done: 2234627
# Episode: 29870, Score: 0, Reward: 6.999999999999988, Steps done: 2234708
# Episode: 29871, Score: 1, Reward: 7.999999999999984, Steps done: 2234799
# Episode: 29872, Score: 3, Reward: 22.500000000000057, Steps done: 2235008
# Episode: 29873, Score: 1, Reward: 11.899999999999974, Steps done: 2235129
# Episode: 29874, Score: 3, Reward: 23.300000000000068, Steps done: 2235346
# Episode: 29875, Score: 1, Reward: 9.299999999999983, Steps done: 2235441
# Episode: 29876, Score: 1, Reward: 12.099999999999973, Steps done: 2235564
# Episode: 29877, Score: 1, Reward: 11.999999999999973, Steps done: 2235686
# Episode: 29878, Score: 2, Reward: 17.099999999999994, Steps done: 2235850
# Episode: 29879, Score: 5, Reward: 32.60000000000017, Steps done: 2236142
# Episode: 29880, Score: 3, Reward: 23.100000000000065, Steps done: 2236357
# Episode: 29881, Score: 3, Reward: 20.00000000000002, Steps done: 2236541
# Episode: 29882, Score: 1, Reward: 11.899999999999974, Steps done: 2236662
# Episode: 29883, Score: 1, Reward: 11.899999999999974, Steps done: 2236783
# Episode: 29884, Score: 2, Reward: 17.5, Steps done: 2236951
# Episode: 29885, Score: 0, Reward: 6.799999999999988, Steps done: 2237030
# Episode: 29886, Score: 1, Reward: 11.999999999999973, Steps done: 2237152
# Episode: 29887, Score: 0, Reward: 0.5000000000000002, Steps done: 2237168
# Episode: 29888, Score: 0, Reward: 7.499999999999986, Steps done: 2237254
# Episode: 29889, Score: 1, Reward: 11.899999999999974, Steps done: 2237375
# Episode: 29890, Score: 2, Reward: 17.099999999999994, Steps done: 2237539
# Episode: 29891, Score: 5, Reward: 29.800000000000132, Steps done: 2237803
# Episode: 29892, Score: 1, Reward: 9.099999999999984, Steps done: 2237896
# Episode: 29893, Score: 2, Reward: 16.999999999999993, Steps done: 2238059
# Episode: 29894, Score: 2, Reward: 17.099999999999994, Steps done: 2238223
# Episode: 29895, Score: 12, Reward: 68.60000000000025, Steps done: 2238812
# Episode: 29896, Score: 3, Reward: 19.80000000000002, Steps done: 2238994
# Episode: 29897, Score: 3, Reward: 19.400000000000013, Steps done: 2239172
# Episode: 29898, Score: 1, Reward: 11.899999999999974, Steps done: 2239293
# Episode: 29899, Score: 0, Reward: 6.799999999999988, Steps done: 2239372
# Episode: 29900, Score: 6, Reward: 34.90000000000019, Steps done: 2239678
# Episode: 29901, Score: 5, Reward: 32.60000000000017, Steps done: 2239970
# Episode: 29902, Score: 6, Reward: 37.70000000000023, Steps done: 2240304
# Episode: 29903, Score: 1, Reward: 7.999999999999984, Steps done: 2240395
# Episode: 29904, Score: 1, Reward: 12.599999999999971, Steps done: 2240523
# Episode: 29905, Score: 1, Reward: 11.899999999999974, Steps done: 2240644
# Episode: 29906, Score: 4, Reward: 27.700000000000117, Steps done: 2240896
# Episode: 29907, Score: 3, Reward: 19.400000000000013, Steps done: 2241074
# Episode: 29908, Score: 1, Reward: 9.699999999999982, Steps done: 2241173
# Episode: 29909, Score: 6, Reward: 37.80000000000023, Steps done: 2241508
# Episode: 29910, Score: 2, Reward: 14.399999999999968, Steps done: 2241645
# Episode: 29911, Score: 2, Reward: 17.099999999999994, Steps done: 2241809
# Episode: 29912, Score: 1, Reward: 8.999999999999984, Steps done: 2241901
# Episode: 29913, Score: 2, Reward: 17.099999999999994, Steps done: 2242065
# Episode: 29914, Score: 1, Reward: 11.899999999999974, Steps done: 2242186
# Episode: 29915, Score: 3, Reward: 19.30000000000001, Steps done: 2242363
# Episode: 29916, Score: 3, Reward: 22.300000000000054, Steps done: 2242570
# Episode: 29917, Score: 11, Reward: 63.50000000000048, Steps done: 2243117
# Episode: 29918, Score: 8, Reward: 45.600000000000314, Steps done: 2243512
# Episode: 29919, Score: 16, Reward: 89.1999999999993, Steps done: 2244271
# Episode: 29920, Score: 5, Reward: 31.00000000000015, Steps done: 2244547
# Episode: 29921, Score: 2, Reward: 14.799999999999967, Steps done: 2244688
# Episode: 29922, Score: 1, Reward: 11.899999999999974, Steps done: 2244809
# Episode: 29923, Score: 1, Reward: 9.499999999999982, Steps done: 2244906
# Episode: 29924, Score: 3, Reward: 19.80000000000002, Steps done: 2245088
# Episode: 29925, Score: 3, Reward: 22.300000000000054, Steps done: 2245295
# Episode: 29926, Score: 1, Reward: 13.09999999999997, Steps done: 2245428
# Episode: 29927, Score: 1, Reward: 8.999999999999984, Steps done: 2245520
# Episode: 29928, Score: 5, Reward: 28.60000000000013, Steps done: 2245781
# Episode: 29929, Score: 1, Reward: 9.599999999999982, Steps done: 2245879
# Episode: 29930, Score: 3, Reward: 22.300000000000054, Steps done: 2246086
# Episode: 29931, Score: 1, Reward: 7.999999999999984, Steps done: 2246177
# Episode: 29932, Score: 3, Reward: 19.600000000000016, Steps done: 2246357
# Episode: 29933, Score: 14, Reward: 78.89999999999978, Steps done: 2247031
# Episode: 29934, Score: 0, Reward: 6.799999999999988, Steps done: 2247110
# Episode: 29935, Score: 0, Reward: 6.799999999999988, Steps done: 2247189
# Episode: 29936, Score: 1, Reward: 12.69999999999997, Steps done: 2247318
# Episode: 29937, Score: 4, Reward: 27.600000000000115, Steps done: 2247569
# Episode: 29938, Score: 3, Reward: 19.500000000000014, Steps done: 2247748
# Episode: 29939, Score: 0, Reward: 6.799999999999988, Steps done: 2247827
# Episode: 29940, Score: 0, Reward: 6.799999999999988, Steps done: 2247906
# Episode: 29941, Score: 2, Reward: 17.099999999999994, Steps done: 2248070
# Episode: 29942, Score: 2, Reward: 17.099999999999994, Steps done: 2248234
# Episode: 29943, Score: 4, Reward: 27.400000000000112, Steps done: 2248483
# Episode: 29944, Score: 0, Reward: 7.599999999999985, Steps done: 2248570
# Episode: 29945, Score: 4, Reward: 24.800000000000075, Steps done: 2248793
# Episode: 29946, Score: 4, Reward: 24.50000000000007, Steps done: 2249013
# Episode: 29947, Score: 2, Reward: 17.6, Steps done: 2249182
# Episode: 29948, Score: 0, Reward: 5.499999999999993, Steps done: 2249248
# Episode: 29949, Score: 1, Reward: 11.899999999999974, Steps done: 2249369
# Episode: 29950, Score: 1, Reward: 11.999999999999973, Steps done: 2249491
# Episode: 29951, Score: 0, Reward: 7.099999999999987, Steps done: 2249573
# Episode: 29952, Score: 5, Reward: 32.60000000000017, Steps done: 2249865
# Episode: 29953, Score: 1, Reward: 9.199999999999983, Steps done: 2249959
# Episode: 29954, Score: 0, Reward: 7.799999999999985, Steps done: 2250048
# Episode: 29955, Score: 1, Reward: 12.99999999999997, Steps done: 2250180
# Episode: 29956, Score: 5, Reward: 28.60000000000013, Steps done: 2250441
# Episode: 29957, Score: 13, Reward: 70.80000000000018, Steps done: 2251043
# Episode: 29958, Score: 0, Reward: 7.799999999999985, Steps done: 2251132
# Episode: 29959, Score: 0, Reward: 6.799999999999988, Steps done: 2251211
# Episode: 29960, Score: 1, Reward: 11.899999999999974, Steps done: 2251332
# Episode: 29961, Score: 2, Reward: 17.099999999999994, Steps done: 2251496
# Episode: 29962, Score: 3, Reward: 22.300000000000054, Steps done: 2251703
# Episode: 29963, Score: 2, Reward: 17.099999999999994, Steps done: 2251867
# Episode: 29964, Score: 0, Reward: 0.5000000000000002, Steps done: 2251883
# Episode: 29965, Score: 2, Reward: 17.099999999999994, Steps done: 2252047
# Episode: 29966, Score: 4, Reward: 27.400000000000112, Steps done: 2252296
# Episode: 29967, Score: 1, Reward: 11.899999999999974, Steps done: 2252417
# Episode: 29968, Score: 1, Reward: 12.599999999999971, Steps done: 2252545
# Episode: 29969, Score: 1, Reward: 11.899999999999974, Steps done: 2252666
# Episode: 29970, Score: 4, Reward: 27.500000000000114, Steps done: 2252916
# Episode: 29971, Score: 1, Reward: 12.599999999999971, Steps done: 2253044
# Episode: 29972, Score: 1, Reward: 11.899999999999974, Steps done: 2253165
# Episode: 29973, Score: 6, Reward: 37.70000000000023, Steps done: 2253499
# Episode: 29974, Score: 1, Reward: 12.299999999999972, Steps done: 2253624
# Episode: 29975, Score: 0, Reward: 6.799999999999988, Steps done: 2253703
# Episode: 29976, Score: 8, Reward: 45.40000000000031, Steps done: 2254096
# Episode: 29977, Score: 0, Reward: 6.799999999999988, Steps done: 2254175
# Episode: 29978, Score: 2, Reward: 17.099999999999994, Steps done: 2254339
# Episode: 29979, Score: 0, Reward: 6.799999999999988, Steps done: 2254418
# Episode: 29980, Score: 0, Reward: 6.799999999999988, Steps done: 2254497
# Episode: 29981, Score: 4, Reward: 27.400000000000112, Steps done: 2254746
# Episode: 29982, Score: 1, Reward: 11.899999999999974, Steps done: 2254867
# Episode: 29983, Score: 4, Reward: 27.400000000000112, Steps done: 2255116
# Episode: 29984, Score: 0, Reward: 6.999999999999988, Steps done: 2255197
# Episode: 29985, Score: 4, Reward: 27.400000000000112, Steps done: 2255446
# Episode: 29986, Score: 1, Reward: 9.499999999999982, Steps done: 2255543
# Episode: 29987, Score: 2, Reward: 14.399999999999968, Steps done: 2255680
# Episode: 29988, Score: 2, Reward: 17.800000000000004, Steps done: 2255851
# Episode: 29989, Score: 1, Reward: 11.999999999999973, Steps done: 2255973
# Episode: 29990, Score: 4, Reward: 27.400000000000112, Steps done: 2256222
# Episode: 29991, Score: 6, Reward: 34.90000000000019, Steps done: 2256528
# Episode: 29992, Score: 2, Reward: 14.399999999999968, Steps done: 2256665
# Episode: 29993, Score: 0, Reward: 7.599999999999985, Steps done: 2256752
# Episode: 29994, Score: 1, Reward: 11.999999999999973, Steps done: 2256874
# Episode: 29995, Score: 1, Reward: 11.899999999999974, Steps done: 2256995
# Episode: 29996, Score: 3, Reward: 22.900000000000063, Steps done: 2257208
# Episode: 29997, Score: 0, Reward: 7.799999999999985, Steps done: 2257297
# Episode: 29998, Score: 2, Reward: 18.10000000000001, Steps done: 2257471
# Episode: 29999, Score: 5, Reward: 32.50000000000017, Steps done: 2257762
# Episode: 30000, Score: 5, Reward: 30.100000000000136, Steps done: 2258029
# Episode: 30001, Score: 0, Reward: 6.799999999999988, Steps done: 2258108
# Episode: 30002, Score: 1, Reward: 13.09999999999997, Steps done: 2258241
# Episode: 30003, Score: 0, Reward: 6.799999999999988, Steps done: 2258320
# Episode: 30004, Score: 3, Reward: 19.90000000000002, Steps done: 2258503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-5d92311b95b5> in <module>()
#      58         # epsilon-greedy search (select action)
#      59         action = select_action(state)
# ---> 60         screen, reward, done = env.step(action.item())
#      61         rewards += reward
#      62
#
# <ipython-input-26-de12eacd92d4> in step(self, action)
#     166             self.bird, self.bird_rect = self.bird_animation()
#     167
# --> 168         if self._is_collided():
#     169             reward = -1
#     170             terminal = True
#
# <ipython-input-26-de12eacd92d4> in _is_collided(self)
#      92                 for j in range(columns):
#      93                     # posx, posy = self.bird_rect.x + j, self.bird_rect.y + i
# ---> 94                     posx, posy = self.bird_rect.x + i, self.bird_rect.y + j
#      95                     if mask[i, j] and lx < posx < rx and ty < posy < by:
#      96                         return True
#
# KeyboardInterrupt:
